# %% [markdown]
# <a href="https://colab.research.google.com/github/taylorp-j/NGG6050/blob/main/9_20_24_Multiple_Comparisons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Load Required Modules
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
from IPython.display import display, clear_output

# %% [markdown]
# First, simulate multiple (say, 1000) t-tests comparing two samples with equal means and standard deviations, and save the p-values.

# %%
# Parameters
mu_1 = 5
mu_2 = 5
sigma = 1
N = 10
num_simulations = 1000

# Generate Samples and perform t-tests for all simulations
p_values = []
for _ in range(num_simulations):
    X1 = np.random.normal(mu_1, sigma, N)
    X2 = np.random.normal(mu_2, sigma, N)
    tstat, p_val = st.ttest_ind(X1, X2)
    p_values.append(p_val)

#List of Simulation Numbers and p-values
alpha = 0.05
print("Simulation Number and p-values:")
for sim_num, p_val in enumerate(p_values, start=1):
    print(f"Simulation {sim_num}: p-value = {p_val:.4f}")

#Percentage of significant results out of all Simulations
significant_results = [p_val for p_val in p_values if p_val < alpha]
percentage_significant = (len(significant_results) / num_simulations) * 100
print(f"\nPercentage of simulations yielding a statistically significant result: {percentage_significant:.2f}%")
# Out:
# Simulation Number and p-values:
# Simulation 1: p-value = 0.4199
# Simulation 2: p-value = 0.9450
# Simulation 3: p-value = 0.1182
# Simulation 4: p-value = 0.9149
# Simulation 5: p-value = 0.6063
# Simulation 6: p-value = 0.0002
# Simulation 7: p-value = 0.8545
# Simulation 8: p-value = 0.4313
# Simulation 9: p-value = 0.0145
# Simulation 10: p-value = 0.6600
# Simulation 11: p-value = 0.5283
# Simulation 12: p-value = 0.7479
# Simulation 13: p-value = 0.4245
# Simulation 14: p-value = 0.9594
# Simulation 15: p-value = 0.6257
# Simulation 16: p-value = 0.2304
# Simulation 17: p-value = 0.9024
# Simulation 18: p-value = 0.5257
# Simulation 19: p-value = 0.2939
# Simulation 20: p-value = 0.2590
# Simulation 21: p-value = 0.3258
# Simulation 22: p-value = 0.7431
# Simulation 23: p-value = 0.7905
# Simulation 24: p-value = 0.1512
# Simulation 25: p-value = 0.1769
# Simulation 26: p-value = 0.4748
# Simulation 27: p-value = 0.2060
# Simulation 28: p-value = 0.1408
# Simulation 29: p-value = 0.7421
# Simulation 30: p-value = 0.6793
# Simulation 31: p-value = 0.7078
# Simulation 32: p-value = 0.9531
# Simulation 33: p-value = 0.0225
# Simulation 34: p-value = 0.2411
# Simulation 35: p-value = 0.6955
# Simulation 36: p-value = 0.2958
# Simulation 37: p-value = 0.5240
# Simulation 38: p-value = 0.3631
# Simulation 39: p-value = 0.5423
# Simulation 40: p-value = 0.3668
# Simulation 41: p-value = 0.9906
# Simulation 42: p-value = 0.6076
# Simulation 43: p-value = 0.5756
# Simulation 44: p-value = 0.9385
# Simulation 45: p-value = 0.9983
# Simulation 46: p-value = 0.5377
# Simulation 47: p-value = 0.7735
# Simulation 48: p-value = 0.4450
# Simulation 49: p-value = 0.7799
# Simulation 50: p-value = 0.5747
# Simulation 51: p-value = 0.9876
# Simulation 52: p-value = 0.8893
# Simulation 53: p-value = 0.3409
# Simulation 54: p-value = 0.9070
# Simulation 55: p-value = 0.8060
# Simulation 56: p-value = 0.5193
# Simulation 57: p-value = 0.9138
# Simulation 58: p-value = 0.7837
# Simulation 59: p-value = 0.5347
# Simulation 60: p-value = 0.4040
# Simulation 61: p-value = 0.4348
# Simulation 62: p-value = 0.3881
# Simulation 63: p-value = 0.5467
# Simulation 64: p-value = 0.9431
# Simulation 65: p-value = 0.3287
# Simulation 66: p-value = 0.3160
# Simulation 67: p-value = 0.0468
# Simulation 68: p-value = 0.2376
# Simulation 69: p-value = 0.6019
# Simulation 70: p-value = 0.4718
# Simulation 71: p-value = 0.3799
# Simulation 72: p-value = 0.0906
# Simulation 73: p-value = 0.3272
# Simulation 74: p-value = 0.4796
# Simulation 75: p-value = 0.8927
# Simulation 76: p-value = 0.3125
# Simulation 77: p-value = 0.7273
# Simulation 78: p-value = 0.6013
# Simulation 79: p-value = 0.2814
# Simulation 80: p-value = 0.0355
# Simulation 81: p-value = 0.3422
# Simulation 82: p-value = 0.1466
# Simulation 83: p-value = 0.9405
# Simulation 84: p-value = 0.9293
# Simulation 85: p-value = 0.3369
# Simulation 86: p-value = 0.2747
# Simulation 87: p-value = 0.6488
# Simulation 88: p-value = 0.4797
# Simulation 89: p-value = 0.3371
# Simulation 90: p-value = 0.3561
# Simulation 91: p-value = 0.8294
# Simulation 92: p-value = 0.4081
# Simulation 93: p-value = 0.8809
# Simulation 94: p-value = 0.0948
# Simulation 95: p-value = 0.4152
# Simulation 96: p-value = 0.8186
# Simulation 97: p-value = 0.1332
# Simulation 98: p-value = 0.8457
# Simulation 99: p-value = 0.4070
# Simulation 100: p-value = 0.4623
# Simulation 101: p-value = 0.6739
# Simulation 102: p-value = 0.3514
# Simulation 103: p-value = 0.2340
# Simulation 104: p-value = 0.3870
# Simulation 105: p-value = 0.2536
# Simulation 106: p-value = 0.2897
# Simulation 107: p-value = 0.8355
# Simulation 108: p-value = 0.1110
# Simulation 109: p-value = 0.8588
# Simulation 110: p-value = 0.2336
# Simulation 111: p-value = 0.1416
# Simulation 112: p-value = 0.9150
# Simulation 113: p-value = 0.6418
# Simulation 114: p-value = 0.4045
# Simulation 115: p-value = 0.2351
# Simulation 116: p-value = 0.4081
# Simulation 117: p-value = 0.0832
# Simulation 118: p-value = 0.9567
# Simulation 119: p-value = 0.9562
# Simulation 120: p-value = 0.3542
# Simulation 121: p-value = 0.9502
# Simulation 122: p-value = 0.2649
# Simulation 123: p-value = 0.8619
# Simulation 124: p-value = 0.2347
# Simulation 125: p-value = 0.0115
# Simulation 126: p-value = 0.4847
# Simulation 127: p-value = 0.5026
# Simulation 128: p-value = 0.8925
# Simulation 129: p-value = 0.4948
# Simulation 130: p-value = 0.1825
# Simulation 131: p-value = 0.6206
# Simulation 132: p-value = 0.6971
# Simulation 133: p-value = 0.0693
# Simulation 134: p-value = 0.0904
# Simulation 135: p-value = 0.4349
# Simulation 136: p-value = 0.6630
# Simulation 137: p-value = 0.1302
# Simulation 138: p-value = 0.9181
# Simulation 139: p-value = 0.1175
# Simulation 140: p-value = 0.8161
# Simulation 141: p-value = 0.6001
# Simulation 142: p-value = 0.1174
# Simulation 143: p-value = 0.0589
# Simulation 144: p-value = 0.0703
# Simulation 145: p-value = 0.6302
# Simulation 146: p-value = 0.4816
# Simulation 147: p-value = 0.7969
# Simulation 148: p-value = 0.3957
# Simulation 149: p-value = 0.6742
# Simulation 150: p-value = 0.4025
# Simulation 151: p-value = 0.5117
# Simulation 152: p-value = 0.4792
# Simulation 153: p-value = 0.2322
# Simulation 154: p-value = 0.2873
# Simulation 155: p-value = 0.8362
# Simulation 156: p-value = 0.9961
# Simulation 157: p-value = 0.5397
# Simulation 158: p-value = 0.3731
# Simulation 159: p-value = 0.4517
# Simulation 160: p-value = 0.6753
# Simulation 161: p-value = 0.7422
# Simulation 162: p-value = 0.9698
# Simulation 163: p-value = 0.8041
# Simulation 164: p-value = 0.7353
# Simulation 165: p-value = 0.7510
# Simulation 166: p-value = 0.1943
# Simulation 167: p-value = 0.1708
# Simulation 168: p-value = 0.5797
# Simulation 169: p-value = 0.1223
# Simulation 170: p-value = 0.4666
# Simulation 171: p-value = 0.7844
# Simulation 172: p-value = 0.6777
# Simulation 173: p-value = 0.1002
# Simulation 174: p-value = 0.8433
# Simulation 175: p-value = 0.6053
# Simulation 176: p-value = 0.9725
# Simulation 177: p-value = 0.8468
# Simulation 178: p-value = 0.1196
# Simulation 179: p-value = 0.8452
# Simulation 180: p-value = 0.6143
# Simulation 181: p-value = 0.2981
# Simulation 182: p-value = 0.0250
# Simulation 183: p-value = 0.4854
# Simulation 184: p-value = 0.2925
# Simulation 185: p-value = 0.1083
# Simulation 186: p-value = 0.9252
# Simulation 187: p-value = 0.8638
# Simulation 188: p-value = 0.0516
# Simulation 189: p-value = 0.0650
# Simulation 190: p-value = 0.1821
# Simulation 191: p-value = 0.2481
# Simulation 192: p-value = 0.0508
# Simulation 193: p-value = 0.6539
# Simulation 194: p-value = 0.6661
# Simulation 195: p-value = 0.5993
# Simulation 196: p-value = 0.6979
# Simulation 197: p-value = 0.5766
# Simulation 198: p-value = 0.2149
# Simulation 199: p-value = 0.2658
# Simulation 200: p-value = 0.1277
# Simulation 201: p-value = 0.5516
# Simulation 202: p-value = 0.5429
# Simulation 203: p-value = 0.2566
# Simulation 204: p-value = 0.2930
# Simulation 205: p-value = 0.9874
# Simulation 206: p-value = 0.5450
# Simulation 207: p-value = 0.5183
# Simulation 208: p-value = 0.2888
# Simulation 209: p-value = 0.2777
# Simulation 210: p-value = 0.3114
# Simulation 211: p-value = 0.7674
# Simulation 212: p-value = 0.7326
# Simulation 213: p-value = 0.1026
# Simulation 214: p-value = 0.3405
# Simulation 215: p-value = 0.9450
# Simulation 216: p-value = 0.4758
# Simulation 217: p-value = 0.9689
# Simulation 218: p-value = 0.4243
# Simulation 219: p-value = 0.1615
# Simulation 220: p-value = 0.9545
# Simulation 221: p-value = 0.3799
# Simulation 222: p-value = 0.9513
# Simulation 223: p-value = 0.7886
# Simulation 224: p-value = 0.1245
# Simulation 225: p-value = 0.4690
# Simulation 226: p-value = 0.7187
# Simulation 227: p-value = 0.5910
# Simulation 228: p-value = 0.9936
# Simulation 229: p-value = 0.5105
# Simulation 230: p-value = 0.6030
# Simulation 231: p-value = 0.6577
# Simulation 232: p-value = 0.0591
# Simulation 233: p-value = 0.6532
# Simulation 234: p-value = 0.6388
# Simulation 235: p-value = 0.8013
# Simulation 236: p-value = 0.3152
# Simulation 237: p-value = 0.6538
# Simulation 238: p-value = 0.5484
# Simulation 239: p-value = 0.0296
# Simulation 240: p-value = 0.8823
# Simulation 241: p-value = 0.0126
# Simulation 242: p-value = 0.8359
# Simulation 243: p-value = 0.9076
# Simulation 244: p-value = 0.7241
# Simulation 245: p-value = 0.7823
# Simulation 246: p-value = 0.3096
# Simulation 247: p-value = 0.1384
# Simulation 248: p-value = 0.3070
# Simulation 249: p-value = 0.5793
# Simulation 250: p-value = 0.0690
# Simulation 251: p-value = 0.2464
# Simulation 252: p-value = 0.8194
# Simulation 253: p-value = 0.4428
# Simulation 254: p-value = 0.4087
# Simulation 255: p-value = 0.4875
# Simulation 256: p-value = 0.7490
# Simulation 257: p-value = 0.2050
# Simulation 258: p-value = 0.9093
# Simulation 259: p-value = 0.0916
# Simulation 260: p-value = 0.8993
# Simulation 261: p-value = 0.9737
# Simulation 262: p-value = 0.6283
# Simulation 263: p-value = 0.9602
# Simulation 264: p-value = 0.4168
# Simulation 265: p-value = 0.1621
# Simulation 266: p-value = 0.0174
# Simulation 267: p-value = 0.2565
# Simulation 268: p-value = 0.9054
# Simulation 269: p-value = 0.7655
# Simulation 270: p-value = 0.8705
# Simulation 271: p-value = 0.4201
# Simulation 272: p-value = 0.8047
# Simulation 273: p-value = 0.7878
# Simulation 274: p-value = 0.7882
# Simulation 275: p-value = 0.4985
# Simulation 276: p-value = 0.4668
# Simulation 277: p-value = 0.0595
# Simulation 278: p-value = 0.8568
# Simulation 279: p-value = 0.0251
# Simulation 280: p-value = 0.3368
# Simulation 281: p-value = 0.6549
# Simulation 282: p-value = 0.1519
# Simulation 283: p-value = 0.4330
# Simulation 284: p-value = 0.5304
# Simulation 285: p-value = 0.2105
# Simulation 286: p-value = 0.9301
# Simulation 287: p-value = 0.0947
# Simulation 288: p-value = 0.3079
# Simulation 289: p-value = 0.7758
# Simulation 290: p-value = 0.7124
# Simulation 291: p-value = 0.8867
# Simulation 292: p-value = 0.7534
# Simulation 293: p-value = 0.5920
# Simulation 294: p-value = 0.0102
# Simulation 295: p-value = 0.4602
# Simulation 296: p-value = 0.0996
# Simulation 297: p-value = 0.6082
# Simulation 298: p-value = 0.8357
# Simulation 299: p-value = 0.2237
# Simulation 300: p-value = 0.9467
# Simulation 301: p-value = 0.4696
# Simulation 302: p-value = 0.7798
# Simulation 303: p-value = 0.9927
# Simulation 304: p-value = 0.6130
# Simulation 305: p-value = 0.9386
# Simulation 306: p-value = 0.1508
# Simulation 307: p-value = 0.1089
# Simulation 308: p-value = 0.3187
# Simulation 309: p-value = 0.3210
# Simulation 310: p-value = 0.5258
# Simulation 311: p-value = 0.5439
# Simulation 312: p-value = 0.2418
# Simulation 313: p-value = 0.0332
# Simulation 314: p-value = 0.2947
# Simulation 315: p-value = 0.6966
# Simulation 316: p-value = 0.0310
# Simulation 317: p-value = 0.2309
# Simulation 318: p-value = 0.1268
# Simulation 319: p-value = 0.8853
# Simulation 320: p-value = 0.1462
# Simulation 321: p-value = 0.6456
# Simulation 322: p-value = 0.6474
# Simulation 323: p-value = 0.0440
# Simulation 324: p-value = 0.8085
# Simulation 325: p-value = 0.0631
# Simulation 326: p-value = 0.2344
# Simulation 327: p-value = 0.9164
# Simulation 328: p-value = 0.1853
# Simulation 329: p-value = 0.6813
# Simulation 330: p-value = 0.7211
# Simulation 331: p-value = 0.4562
# Simulation 332: p-value = 0.3012
# Simulation 333: p-value = 0.3361
# Simulation 334: p-value = 0.1634
# Simulation 335: p-value = 0.8997
# Simulation 336: p-value = 0.3241
# Simulation 337: p-value = 0.7437
# Simulation 338: p-value = 0.8775
# Simulation 339: p-value = 0.7254
# Simulation 340: p-value = 0.1595
# Simulation 341: p-value = 0.3164
# Simulation 342: p-value = 0.7694
# Simulation 343: p-value = 0.7969
# Simulation 344: p-value = 0.5679
# Simulation 345: p-value = 0.6866
# Simulation 346: p-value = 0.2933
# Simulation 347: p-value = 0.2228
# Simulation 348: p-value = 0.7057
# Simulation 349: p-value = 0.4950
# Simulation 350: p-value = 0.1424
# Simulation 351: p-value = 0.5973
# Simulation 352: p-value = 0.9654
# Simulation 353: p-value = 0.2831
# Simulation 354: p-value = 0.8516
# Simulation 355: p-value = 0.5766
# Simulation 356: p-value = 0.0064
# Simulation 357: p-value = 0.8263
# Simulation 358: p-value = 0.9654
# Simulation 359: p-value = 0.5575
# Simulation 360: p-value = 0.5116
# Simulation 361: p-value = 0.3499
# Simulation 362: p-value = 0.8958
# Simulation 363: p-value = 0.2450
# Simulation 364: p-value = 0.8196
# Simulation 365: p-value = 0.4359
# Simulation 366: p-value = 0.2967
# Simulation 367: p-value = 0.7964
# Simulation 368: p-value = 0.4838
# Simulation 369: p-value = 0.2121
# Simulation 370: p-value = 0.3793
# Simulation 371: p-value = 0.8690
# Simulation 372: p-value = 0.0313
# Simulation 373: p-value = 0.4648
# Simulation 374: p-value = 0.9031
# Simulation 375: p-value = 0.1182
# Simulation 376: p-value = 0.0242
# Simulation 377: p-value = 0.9010
# Simulation 378: p-value = 0.2274
# Simulation 379: p-value = 0.2467
# Simulation 380: p-value = 0.2985
# Simulation 381: p-value = 0.6348
# Simulation 382: p-value = 0.4192
# Simulation 383: p-value = 0.7092
# Simulation 384: p-value = 0.2595
# Simulation 385: p-value = 0.4069
# Simulation 386: p-value = 0.2697
# Simulation 387: p-value = 0.2415
# Simulation 388: p-value = 0.1727
# Simulation 389: p-value = 0.4306
# Simulation 390: p-value = 0.4985
# Simulation 391: p-value = 0.5166
# Simulation 392: p-value = 0.6369
# Simulation 393: p-value = 0.6956
# Simulation 394: p-value = 0.4757
# Simulation 395: p-value = 0.0963
# Simulation 396: p-value = 0.7830
# Simulation 397: p-value = 0.6516
# Simulation 398: p-value = 0.4003
# Simulation 399: p-value = 0.8742
# Simulation 400: p-value = 0.0538
# Simulation 401: p-value = 0.1180
# Simulation 402: p-value = 0.9726
# Simulation 403: p-value = 0.3458
# Simulation 404: p-value = 0.8119
# Simulation 405: p-value = 0.8495
# Simulation 406: p-value = 0.5445
# Simulation 407: p-value = 0.1830
# Simulation 408: p-value = 0.0329
# Simulation 409: p-value = 0.4031
# Simulation 410: p-value = 0.2126
# Simulation 411: p-value = 0.4911
# Simulation 412: p-value = 0.0017
# Simulation 413: p-value = 0.4490
# Simulation 414: p-value = 0.2848
# Simulation 415: p-value = 0.9729
# Simulation 416: p-value = 0.8666
# Simulation 417: p-value = 0.8556
# Simulation 418: p-value = 0.4394
# Simulation 419: p-value = 0.3985
# Simulation 420: p-value = 0.9543
# Simulation 421: p-value = 0.5471
# Simulation 422: p-value = 0.6818
# Simulation 423: p-value = 0.5987
# Simulation 424: p-value = 0.6245
# Simulation 425: p-value = 0.1885
# Simulation 426: p-value = 0.4049
# Simulation 427: p-value = 0.2635
# Simulation 428: p-value = 0.8076
# Simulation 429: p-value = 0.8009
# Simulation 430: p-value = 0.0129
# Simulation 431: p-value = 0.3269
# Simulation 432: p-value = 0.7064
# Simulation 433: p-value = 0.1113
# Simulation 434: p-value = 0.5409
# Simulation 435: p-value = 0.6325
# Simulation 436: p-value = 0.3584
# Simulation 437: p-value = 0.6015
# Simulation 438: p-value = 0.0292
# Simulation 439: p-value = 0.2980
# Simulation 440: p-value = 0.8871
# Simulation 441: p-value = 0.2792
# Simulation 442: p-value = 0.5417
# Simulation 443: p-value = 0.4822
# Simulation 444: p-value = 0.6506
# Simulation 445: p-value = 0.4740
# Simulation 446: p-value = 0.2173
# Simulation 447: p-value = 0.3761
# Simulation 448: p-value = 0.6191
# Simulation 449: p-value = 0.6833
# Simulation 450: p-value = 0.8554
# Simulation 451: p-value = 0.9184
# Simulation 452: p-value = 0.4489
# Simulation 453: p-value = 0.8770
# Simulation 454: p-value = 0.8119
# Simulation 455: p-value = 0.5080
# Simulation 456: p-value = 0.6477
# Simulation 457: p-value = 0.4982
# Simulation 458: p-value = 0.6012
# Simulation 459: p-value = 0.7537
# Simulation 460: p-value = 0.7414
# Simulation 461: p-value = 0.8363
# Simulation 462: p-value = 0.2771
# Simulation 463: p-value = 0.5984
# Simulation 464: p-value = 0.4476
# Simulation 465: p-value = 0.5719
# Simulation 466: p-value = 0.0370
# Simulation 467: p-value = 0.5934
# Simulation 468: p-value = 0.0266
# Simulation 469: p-value = 0.5741
# Simulation 470: p-value = 0.5612
# Simulation 471: p-value = 0.0529
# Simulation 472: p-value = 0.6836
# Simulation 473: p-value = 0.0059
# Simulation 474: p-value = 0.9297
# Simulation 475: p-value = 0.1962
# Simulation 476: p-value = 0.8637
# Simulation 477: p-value = 0.3051
# Simulation 478: p-value = 0.4743
# Simulation 479: p-value = 0.8579
# Simulation 480: p-value = 0.2244
# Simulation 481: p-value = 0.9154
# Simulation 482: p-value = 0.6985
# Simulation 483: p-value = 0.2315
# Simulation 484: p-value = 0.8854
# Simulation 485: p-value = 0.4982
# Simulation 486: p-value = 0.6733
# Simulation 487: p-value = 0.1024
# Simulation 488: p-value = 0.1436
# Simulation 489: p-value = 0.3316
# Simulation 490: p-value = 0.6272
# Simulation 491: p-value = 0.5780
# Simulation 492: p-value = 0.7572
# Simulation 493: p-value = 0.9599
# Simulation 494: p-value = 0.2536
# Simulation 495: p-value = 0.3339
# Simulation 496: p-value = 0.2728
# Simulation 497: p-value = 0.2539
# Simulation 498: p-value = 0.1605
# Simulation 499: p-value = 0.8303
# Simulation 500: p-value = 0.0953
# Simulation 501: p-value = 0.8468
# Simulation 502: p-value = 0.0696
# Simulation 503: p-value = 0.7036
# Simulation 504: p-value = 0.1057
# Simulation 505: p-value = 0.7709
# Simulation 506: p-value = 0.1702
# Simulation 507: p-value = 0.2511
# Simulation 508: p-value = 0.4801
# Simulation 509: p-value = 0.7169
# Simulation 510: p-value = 0.5034
# Simulation 511: p-value = 0.1954
# Simulation 512: p-value = 0.3602
# Simulation 513: p-value = 0.1983
# Simulation 514: p-value = 0.4364
# Simulation 515: p-value = 0.0847
# Simulation 516: p-value = 0.9934
# Simulation 517: p-value = 0.9148
# Simulation 518: p-value = 0.1558
# Simulation 519: p-value = 0.8852
# Simulation 520: p-value = 0.5562
# Simulation 521: p-value = 0.1732
# Simulation 522: p-value = 0.5220
# Simulation 523: p-value = 0.1522
# Simulation 524: p-value = 0.1547
# Simulation 525: p-value = 0.5884
# Simulation 526: p-value = 0.1494
# Simulation 527: p-value = 0.1918
# Simulation 528: p-value = 0.6290
# Simulation 529: p-value = 0.9956
# Simulation 530: p-value = 0.2639
# Simulation 531: p-value = 0.9657
# Simulation 532: p-value = 0.8511
# Simulation 533: p-value = 0.0215
# Simulation 534: p-value = 0.6152
# Simulation 535: p-value = 0.5494
# Simulation 536: p-value = 0.8326
# Simulation 537: p-value = 0.4305
# Simulation 538: p-value = 0.2027
# Simulation 539: p-value = 0.1793
# Simulation 540: p-value = 0.9736
# Simulation 541: p-value = 0.5068
# Simulation 542: p-value = 0.6502
# Simulation 543: p-value = 0.1495
# Simulation 544: p-value = 0.6934
# Simulation 545: p-value = 0.3670
# Simulation 546: p-value = 0.0567
# Simulation 547: p-value = 0.1133
# Simulation 548: p-value = 0.5585
# Simulation 549: p-value = 0.7296
# Simulation 550: p-value = 0.6780
# Simulation 551: p-value = 0.3785
# Simulation 552: p-value = 0.2704
# Simulation 553: p-value = 0.1015
# Simulation 554: p-value = 0.4919
# Simulation 555: p-value = 0.2164
# Simulation 556: p-value = 0.3589
# Simulation 557: p-value = 0.9707
# Simulation 558: p-value = 0.3585
# Simulation 559: p-value = 0.9863
# Simulation 560: p-value = 0.1828
# Simulation 561: p-value = 0.6291
# Simulation 562: p-value = 0.5663
# Simulation 563: p-value = 0.7074
# Simulation 564: p-value = 0.2939
# Simulation 565: p-value = 0.9172
# Simulation 566: p-value = 0.2835
# Simulation 567: p-value = 0.9186
# Simulation 568: p-value = 0.1483
# Simulation 569: p-value = 0.7021
# Simulation 570: p-value = 0.1938
# Simulation 571: p-value = 0.0857
# Simulation 572: p-value = 0.7766
# Simulation 573: p-value = 0.9972
# Simulation 574: p-value = 0.9791
# Simulation 575: p-value = 0.6680
# Simulation 576: p-value = 0.3406
# Simulation 577: p-value = 0.5960
# Simulation 578: p-value = 0.8989
# Simulation 579: p-value = 0.7736
# Simulation 580: p-value = 0.9615
# Simulation 581: p-value = 0.0266
# Simulation 582: p-value = 0.3866
# Simulation 583: p-value = 0.0868
# Simulation 584: p-value = 0.7673
# Simulation 585: p-value = 0.6502
# Simulation 586: p-value = 0.0337
# Simulation 587: p-value = 0.8345
# Simulation 588: p-value = 0.4490
# Simulation 589: p-value = 0.0204
# Simulation 590: p-value = 0.5920
# Simulation 591: p-value = 0.2443
# Simulation 592: p-value = 0.9416
# Simulation 593: p-value = 0.6064
# Simulation 594: p-value = 0.2790
# Simulation 595: p-value = 0.7016
# Simulation 596: p-value = 0.7484
# Simulation 597: p-value = 0.5969
# Simulation 598: p-value = 0.4918
# Simulation 599: p-value = 0.4164
# Simulation 600: p-value = 0.0785
# Simulation 601: p-value = 0.1879
# Simulation 602: p-value = 0.1353
# Simulation 603: p-value = 0.2807
# Simulation 604: p-value = 0.8578
# Simulation 605: p-value = 0.8168
# Simulation 606: p-value = 0.7449
# Simulation 607: p-value = 0.4667
# Simulation 608: p-value = 0.5997
# Simulation 609: p-value = 0.7531
# Simulation 610: p-value = 0.0868
# Simulation 611: p-value = 0.6783
# Simulation 612: p-value = 0.8468
# Simulation 613: p-value = 0.5942
# Simulation 614: p-value = 0.9291
# Simulation 615: p-value = 0.7456
# Simulation 616: p-value = 0.9905
# Simulation 617: p-value = 0.8426
# Simulation 618: p-value = 0.5678
# Simulation 619: p-value = 0.4211
# Simulation 620: p-value = 0.8732
# Simulation 621: p-value = 0.7490
# Simulation 622: p-value = 0.9311
# Simulation 623: p-value = 0.6854
# Simulation 624: p-value = 0.2061
# Simulation 625: p-value = 0.1941
# Simulation 626: p-value = 0.8110
# Simulation 627: p-value = 0.7711
# Simulation 628: p-value = 0.4996
# Simulation 629: p-value = 0.3461
# Simulation 630: p-value = 0.5109
# Simulation 631: p-value = 0.9555
# Simulation 632: p-value = 0.8102
# Simulation 633: p-value = 0.7192
# Simulation 634: p-value = 0.3914
# Simulation 635: p-value = 0.8215
# Simulation 636: p-value = 0.9049
# Simulation 637: p-value = 0.9903
# Simulation 638: p-value = 0.9208
# Simulation 639: p-value = 0.4613
# Simulation 640: p-value = 0.8538
# Simulation 641: p-value = 0.5024
# Simulation 642: p-value = 0.4471
# Simulation 643: p-value = 0.0974
# Simulation 644: p-value = 0.6963
# Simulation 645: p-value = 0.1259
# Simulation 646: p-value = 0.9826
# Simulation 647: p-value = 0.4828
# Simulation 648: p-value = 0.9987
# Simulation 649: p-value = 0.4620
# Simulation 650: p-value = 0.6487
# Simulation 651: p-value = 0.4914
# Simulation 652: p-value = 0.2114
# Simulation 653: p-value = 0.2365
# Simulation 654: p-value = 0.1439
# Simulation 655: p-value = 0.5026
# Simulation 656: p-value = 0.9100
# Simulation 657: p-value = 0.3478
# Simulation 658: p-value = 0.6428
# Simulation 659: p-value = 0.4338
# Simulation 660: p-value = 0.9680
# Simulation 661: p-value = 0.1734
# Simulation 662: p-value = 0.2777
# Simulation 663: p-value = 0.4269
# Simulation 664: p-value = 0.1223
# Simulation 665: p-value = 0.5263
# Simulation 666: p-value = 0.8043
# Simulation 667: p-value = 0.9801
# Simulation 668: p-value = 0.1881
# Simulation 669: p-value = 0.0111
# Simulation 670: p-value = 0.1250
# Simulation 671: p-value = 0.6554
# Simulation 672: p-value = 0.7988
# Simulation 673: p-value = 0.4409
# Simulation 674: p-value = 0.1850
# Simulation 675: p-value = 0.8920
# Simulation 676: p-value = 0.9798
# Simulation 677: p-value = 0.4622
# Simulation 678: p-value = 0.0633
# Simulation 679: p-value = 0.0165
# Simulation 680: p-value = 0.9278
# Simulation 681: p-value = 0.8986
# Simulation 682: p-value = 0.5011
# Simulation 683: p-value = 0.1076
# Simulation 684: p-value = 0.5073
# Simulation 685: p-value = 0.8202
# Simulation 686: p-value = 0.3158
# Simulation 687: p-value = 0.0689
# Simulation 688: p-value = 0.7625
# Simulation 689: p-value = 0.5184
# Simulation 690: p-value = 0.0333
# Simulation 691: p-value = 0.3573
# Simulation 692: p-value = 0.0464
# Simulation 693: p-value = 0.7683
# Simulation 694: p-value = 0.9032
# Simulation 695: p-value = 0.5357
# Simulation 696: p-value = 0.4317
# Simulation 697: p-value = 0.0302
# Simulation 698: p-value = 0.4923
# Simulation 699: p-value = 0.3941
# Simulation 700: p-value = 0.3568
# Simulation 701: p-value = 0.3333
# Simulation 702: p-value = 0.9862
# Simulation 703: p-value = 0.9398
# Simulation 704: p-value = 0.1354
# Simulation 705: p-value = 0.9490
# Simulation 706: p-value = 0.9734
# Simulation 707: p-value = 0.2097
# Simulation 708: p-value = 0.7337
# Simulation 709: p-value = 0.3867
# Simulation 710: p-value = 0.4035
# Simulation 711: p-value = 0.9545
# Simulation 712: p-value = 0.0003
# Simulation 713: p-value = 0.0670
# Simulation 714: p-value = 0.0927
# Simulation 715: p-value = 0.9563
# Simulation 716: p-value = 0.1901
# Simulation 717: p-value = 0.9751
# Simulation 718: p-value = 0.9365
# Simulation 719: p-value = 0.1725
# Simulation 720: p-value = 0.7646
# Simulation 721: p-value = 0.5250
# Simulation 722: p-value = 0.4796
# Simulation 723: p-value = 0.4681
# Simulation 724: p-value = 0.7316
# Simulation 725: p-value = 0.4204
# Simulation 726: p-value = 0.9210
# Simulation 727: p-value = 0.5944
# Simulation 728: p-value = 0.4373
# Simulation 729: p-value = 0.7756
# Simulation 730: p-value = 0.2595
# Simulation 731: p-value = 0.5066
# Simulation 732: p-value = 0.3857
# Simulation 733: p-value = 0.2100
# Simulation 734: p-value = 0.3216
# Simulation 735: p-value = 0.7000
# Simulation 736: p-value = 0.8296
# Simulation 737: p-value = 0.1141
# Simulation 738: p-value = 0.9764
# Simulation 739: p-value = 0.1251
# Simulation 740: p-value = 0.1077
# Simulation 741: p-value = 0.6392
# Simulation 742: p-value = 0.4423
# Simulation 743: p-value = 0.6046
# Simulation 744: p-value = 0.8492
# Simulation 745: p-value = 0.9333
# Simulation 746: p-value = 0.7700
# Simulation 747: p-value = 0.4798
# Simulation 748: p-value = 0.5579
# Simulation 749: p-value = 0.5432
# Simulation 750: p-value = 0.5496
# Simulation 751: p-value = 0.1161
# Simulation 752: p-value = 0.3421
# Simulation 753: p-value = 0.3667
# Simulation 754: p-value = 0.3245
# Simulation 755: p-value = 0.7451
# Simulation 756: p-value = 0.2450
# Simulation 757: p-value = 0.3338
# Simulation 758: p-value = 0.3511
# Simulation 759: p-value = 0.6971
# Simulation 760: p-value = 0.3729
# Simulation 761: p-value = 0.7933
# Simulation 762: p-value = 0.0475
# Simulation 763: p-value = 0.3673
# Simulation 764: p-value = 0.8430
# Simulation 765: p-value = 0.5682
# Simulation 766: p-value = 0.5629
# Simulation 767: p-value = 0.8093
# Simulation 768: p-value = 0.8028
# Simulation 769: p-value = 0.2860
# Simulation 770: p-value = 0.8928
# Simulation 771: p-value = 0.7322
# Simulation 772: p-value = 0.5765
# Simulation 773: p-value = 0.0103
# Simulation 774: p-value = 0.5282
# Simulation 775: p-value = 0.9791
# Simulation 776: p-value = 0.2433
# Simulation 777: p-value = 0.6421
# Simulation 778: p-value = 0.8463
# Simulation 779: p-value = 0.4519
# Simulation 780: p-value = 0.0945
# Simulation 781: p-value = 0.1042
# Simulation 782: p-value = 0.5793
# Simulation 783: p-value = 0.5148
# Simulation 784: p-value = 0.9180
# Simulation 785: p-value = 0.8180
# Simulation 786: p-value = 0.4199
# Simulation 787: p-value = 0.7526
# Simulation 788: p-value = 0.5844
# Simulation 789: p-value = 0.1559
# Simulation 790: p-value = 0.1935
# Simulation 791: p-value = 0.6301
# Simulation 792: p-value = 0.7823
# Simulation 793: p-value = 0.8721
# Simulation 794: p-value = 0.6691
# Simulation 795: p-value = 0.3666
# Simulation 796: p-value = 0.0757
# Simulation 797: p-value = 0.4860
# Simulation 798: p-value = 0.2917
# Simulation 799: p-value = 0.8836
# Simulation 800: p-value = 0.8709
# Simulation 801: p-value = 0.6024
# Simulation 802: p-value = 0.6672
# Simulation 803: p-value = 0.9458
# Simulation 804: p-value = 0.9280
# Simulation 805: p-value = 0.3106
# Simulation 806: p-value = 0.7573
# Simulation 807: p-value = 0.9505
# Simulation 808: p-value = 0.9397
# Simulation 809: p-value = 0.6305
# Simulation 810: p-value = 0.0046
# Simulation 811: p-value = 0.2219
# Simulation 812: p-value = 0.8460
# Simulation 813: p-value = 0.0232
# Simulation 814: p-value = 0.4854
# Simulation 815: p-value = 0.1035
# Simulation 816: p-value = 0.7833
# Simulation 817: p-value = 0.3958
# Simulation 818: p-value = 0.5230
# Simulation 819: p-value = 0.8631
# Simulation 820: p-value = 0.7178
# Simulation 821: p-value = 0.5998
# Simulation 822: p-value = 0.3031
# Simulation 823: p-value = 0.2811
# Simulation 824: p-value = 0.4978
# Simulation 825: p-value = 0.0269
# Simulation 826: p-value = 0.9600
# Simulation 827: p-value = 0.5414
# Simulation 828: p-value = 0.1890
# Simulation 829: p-value = 0.4545
# Simulation 830: p-value = 0.2339
# Simulation 831: p-value = 0.8389
# Simulation 832: p-value = 0.1022
# Simulation 833: p-value = 0.9659
# Simulation 834: p-value = 0.4931
# Simulation 835: p-value = 0.4247
# Simulation 836: p-value = 0.4187
# Simulation 837: p-value = 0.4272
# Simulation 838: p-value = 0.0502
# Simulation 839: p-value = 0.6273
# Simulation 840: p-value = 0.7990
# Simulation 841: p-value = 0.3302
# Simulation 842: p-value = 0.1920
# Simulation 843: p-value = 0.9292
# Simulation 844: p-value = 0.7338
# Simulation 845: p-value = 0.0161
# Simulation 846: p-value = 0.0311
# Simulation 847: p-value = 0.7191
# Simulation 848: p-value = 0.7973
# Simulation 849: p-value = 0.0846
# Simulation 850: p-value = 0.8763
# Simulation 851: p-value = 0.9978
# Simulation 852: p-value = 0.3914
# Simulation 853: p-value = 0.1857
# Simulation 854: p-value = 0.2251
# Simulation 855: p-value = 0.4081
# Simulation 856: p-value = 0.0871
# Simulation 857: p-value = 0.6649
# Simulation 858: p-value = 0.6468
# Simulation 859: p-value = 0.9750
# Simulation 860: p-value = 0.2642
# Simulation 861: p-value = 0.0047
# Simulation 862: p-value = 0.6651
# Simulation 863: p-value = 0.4532
# Simulation 864: p-value = 0.8979
# Simulation 865: p-value = 0.8448
# Simulation 866: p-value = 0.3184
# Simulation 867: p-value = 0.6387
# Simulation 868: p-value = 0.6352
# Simulation 869: p-value = 0.9421
# Simulation 870: p-value = 0.3578
# Simulation 871: p-value = 0.0899
# Simulation 872: p-value = 0.8533
# Simulation 873: p-value = 0.1230
# Simulation 874: p-value = 0.2039
# Simulation 875: p-value = 0.6230
# Simulation 876: p-value = 0.9572
# Simulation 877: p-value = 0.4899
# Simulation 878: p-value = 0.1961
# Simulation 879: p-value = 0.2905
# Simulation 880: p-value = 0.5225
# Simulation 881: p-value = 0.5283
# Simulation 882: p-value = 0.1630
# Simulation 883: p-value = 0.4924
# Simulation 884: p-value = 0.6292
# Simulation 885: p-value = 0.6749
# Simulation 886: p-value = 0.1731
# Simulation 887: p-value = 0.3146
# Simulation 888: p-value = 0.1394
# Simulation 889: p-value = 0.9887
# Simulation 890: p-value = 0.1120
# Simulation 891: p-value = 0.6530
# Simulation 892: p-value = 0.2347
# Simulation 893: p-value = 0.3963
# Simulation 894: p-value = 0.6492
# Simulation 895: p-value = 0.3604
# Simulation 896: p-value = 0.5680
# Simulation 897: p-value = 0.5459
# Simulation 898: p-value = 0.9596
# Simulation 899: p-value = 0.8846
# Simulation 900: p-value = 0.6728
# Simulation 901: p-value = 0.7766
# Simulation 902: p-value = 0.3716
# Simulation 903: p-value = 0.0710
# Simulation 904: p-value = 0.5495
# Simulation 905: p-value = 0.6291
# Simulation 906: p-value = 0.5369
# Simulation 907: p-value = 0.8269
# Simulation 908: p-value = 0.6461
# Simulation 909: p-value = 0.5936
# Simulation 910: p-value = 0.1511
# Simulation 911: p-value = 0.5105
# Simulation 912: p-value = 0.1736
# Simulation 913: p-value = 0.1054
# Simulation 914: p-value = 0.8087
# Simulation 915: p-value = 0.7338
# Simulation 916: p-value = 0.4484
# Simulation 917: p-value = 0.6442
# Simulation 918: p-value = 0.5613
# Simulation 919: p-value = 0.4867
# Simulation 920: p-value = 0.9422
# Simulation 921: p-value = 0.9053
# Simulation 922: p-value = 0.0655
# Simulation 923: p-value = 0.3189
# Simulation 924: p-value = 0.6744
# Simulation 925: p-value = 0.1713
# Simulation 926: p-value = 0.2827
# Simulation 927: p-value = 0.6410
# Simulation 928: p-value = 0.9531
# Simulation 929: p-value = 0.2254
# Simulation 930: p-value = 0.1330
# Simulation 931: p-value = 0.5989
# Simulation 932: p-value = 0.1104
# Simulation 933: p-value = 0.4586
# Simulation 934: p-value = 0.8266
# Simulation 935: p-value = 0.3221
# Simulation 936: p-value = 0.2384
# Simulation 937: p-value = 0.3316
# Simulation 938: p-value = 0.5762
# Simulation 939: p-value = 0.6577
# Simulation 940: p-value = 0.8103
# Simulation 941: p-value = 0.6542
# Simulation 942: p-value = 0.7007
# Simulation 943: p-value = 0.3101
# Simulation 944: p-value = 0.9870
# Simulation 945: p-value = 0.6599
# Simulation 946: p-value = 0.7375
# Simulation 947: p-value = 0.3707
# Simulation 948: p-value = 0.7541
# Simulation 949: p-value = 0.2929
# Simulation 950: p-value = 0.0510
# Simulation 951: p-value = 0.6438
# Simulation 952: p-value = 0.9283
# Simulation 953: p-value = 0.1793
# Simulation 954: p-value = 0.7166
# Simulation 955: p-value = 0.3770
# Simulation 956: p-value = 0.7380
# Simulation 957: p-value = 0.6549
# Simulation 958: p-value = 0.3459
# Simulation 959: p-value = 0.4826
# Simulation 960: p-value = 0.2221
# Simulation 961: p-value = 0.5748
# Simulation 962: p-value = 0.6867
# Simulation 963: p-value = 0.0405
# Simulation 964: p-value = 0.4304
# Simulation 965: p-value = 0.5354
# Simulation 966: p-value = 0.4019
# Simulation 967: p-value = 0.0987
# Simulation 968: p-value = 0.2983
# Simulation 969: p-value = 0.2230
# Simulation 970: p-value = 0.7746
# Simulation 971: p-value = 0.2253
# Simulation 972: p-value = 0.2416
# Simulation 973: p-value = 0.7976
# Simulation 974: p-value = 0.7564
# Simulation 975: p-value = 0.2040
# Simulation 976: p-value = 0.7049
# Simulation 977: p-value = 0.6792
# Simulation 978: p-value = 0.9640
# Simulation 979: p-value = 0.8768
# Simulation 980: p-value = 0.3469
# Simulation 981: p-value = 0.8775
# Simulation 982: p-value = 0.7413
# Simulation 983: p-value = 0.2556
# Simulation 984: p-value = 0.5076
# Simulation 985: p-value = 0.0394
# Simulation 986: p-value = 0.4096
# Simulation 987: p-value = 0.0463
# Simulation 988: p-value = 0.0337
# Simulation 989: p-value = 0.0565
# Simulation 990: p-value = 0.8998
# Simulation 991: p-value = 0.4650
# Simulation 992: p-value = 0.2773
# Simulation 993: p-value = 0.5244
# Simulation 994: p-value = 0.9707
# Simulation 995: p-value = 0.1056
# Simulation 996: p-value = 0.1765
# Simulation 997: p-value = 0.7595
# Simulation 998: p-value = 0.7126
# Simulation 999: p-value = 0.3295
# Simulation 1000: p-value = 0.4385
#
# Percentage of simulations yielding a statistically significant result: 4.70%

# %% [markdown]
# Second, once you have the simulated p-values, apply both methods to address the multiple comparisons problem.

# %% [markdown]
# METHOD 1: Bonferroni Correction

# %%
m = num_simulations
alpha = 0.05
bonferroni_alpha = alpha / m

# Calculate the number of significant results after correction
significant_count = np.sum(p_values < bonferroni_alpha)

# Results
print(f"\nBonferroni corrected alpha: {bonferroni_alpha:.6f}")
print(f'Number of significant p-values after Bonferroni correction: {significant_count}')
# Out:
# Bonferroni corrected alpha: 0.000050
# Number of significant p-values after Bonferroni correction: 0

# %% [markdown]
# METHOD 2: Benjamini-Hochberg Procedure

# %%
#Rank p-values in ascending order
p_values = np.array(p_values)

ranked_indices = np.argsort(p_values)
ranked_p_values = p_values[ranked_indices]

#Critical value for each p-value as (i/n)Q, where i is the rank, n is the total number of tests, and Q is the false discovery rate (a percentage) that you choose (typically 0.05).
Q = 0.05 #false discovery rate
n = len(p_values)
critical_values = (np.arange(1, n + 1) / n) * Q

# Print ranked p-values and their critical values
print("Ranked p-values and their critical values:")
for rank, (p_val, crit_val) in enumerate(zip(ranked_p_values, critical_values), start=1):
    print(f"Rank {rank}: p-value = {p_val:.4f}, critical value = {crit_val:.4f}")

#Find the largest value that is smaller than its associated critical value
valid_p_mask = ranked_p_values < critical_values
if np.any(valid_p_mask):
    largest_valid_p = ranked_p_values[valid_p_mask][-1]  # Take the last valid p-value
    print(f'The largest p-value smaller than its critical value is: {largest_valid_p:.4f}')
else:
    print('No p-values are smaller than their associated critical values.')
# Out:
# Ranked p-values and their critical values:
# Rank 1: p-value = 0.0014, critical value = 0.0001
# Rank 2: p-value = 0.0035, critical value = 0.0001
# Rank 3: p-value = 0.0037, critical value = 0.0002
# Rank 4: p-value = 0.0056, critical value = 0.0002
# Rank 5: p-value = 0.0066, critical value = 0.0003
# Rank 6: p-value = 0.0069, critical value = 0.0003
# Rank 7: p-value = 0.0074, critical value = 0.0004
# Rank 8: p-value = 0.0074, critical value = 0.0004
# Rank 9: p-value = 0.0080, critical value = 0.0004
# Rank 10: p-value = 0.0093, critical value = 0.0005
# Rank 11: p-value = 0.0093, critical value = 0.0006
# Rank 12: p-value = 0.0096, critical value = 0.0006
# Rank 13: p-value = 0.0096, critical value = 0.0006
# Rank 14: p-value = 0.0099, critical value = 0.0007
# Rank 15: p-value = 0.0103, critical value = 0.0008
# Rank 16: p-value = 0.0109, critical value = 0.0008
# Rank 17: p-value = 0.0111, critical value = 0.0009
# Rank 18: p-value = 0.0118, critical value = 0.0009
# Rank 19: p-value = 0.0129, critical value = 0.0009
# Rank 20: p-value = 0.0136, critical value = 0.0010
# Rank 21: p-value = 0.0145, critical value = 0.0011
# Rank 22: p-value = 0.0146, critical value = 0.0011
# Rank 23: p-value = 0.0163, critical value = 0.0011
# Rank 24: p-value = 0.0173, critical value = 0.0012
# Rank 25: p-value = 0.0213, critical value = 0.0013
# Rank 26: p-value = 0.0215, critical value = 0.0013
# Rank 27: p-value = 0.0226, critical value = 0.0014
# Rank 28: p-value = 0.0230, critical value = 0.0014
# Rank 29: p-value = 0.0255, critical value = 0.0015
# Rank 30: p-value = 0.0259, critical value = 0.0015
# Rank 31: p-value = 0.0290, critical value = 0.0016
# Rank 32: p-value = 0.0291, critical value = 0.0016
# Rank 33: p-value = 0.0310, critical value = 0.0017
# Rank 34: p-value = 0.0313, critical value = 0.0017
# Rank 35: p-value = 0.0315, critical value = 0.0018
# Rank 36: p-value = 0.0328, critical value = 0.0018
# Rank 37: p-value = 0.0334, critical value = 0.0019
# Rank 38: p-value = 0.0341, critical value = 0.0019
# Rank 39: p-value = 0.0353, critical value = 0.0020
# Rank 40: p-value = 0.0363, critical value = 0.0020
# Rank 41: p-value = 0.0377, critical value = 0.0021
# Rank 42: p-value = 0.0401, critical value = 0.0021
# Rank 43: p-value = 0.0412, critical value = 0.0022
# Rank 44: p-value = 0.0417, critical value = 0.0022
# Rank 45: p-value = 0.0432, critical value = 0.0022
# Rank 46: p-value = 0.0446, critical value = 0.0023
# Rank 47: p-value = 0.0463, critical value = 0.0024
# Rank 48: p-value = 0.0463, critical value = 0.0024
# Rank 49: p-value = 0.0473, critical value = 0.0025
# Rank 50: p-value = 0.0481, critical value = 0.0025
# Rank 51: p-value = 0.0496, critical value = 0.0026
# Rank 52: p-value = 0.0498, critical value = 0.0026
# Rank 53: p-value = 0.0506, critical value = 0.0027
# Rank 54: p-value = 0.0507, critical value = 0.0027
# Rank 55: p-value = 0.0517, critical value = 0.0028
# Rank 56: p-value = 0.0522, critical value = 0.0028
# Rank 57: p-value = 0.0539, critical value = 0.0029
# Rank 58: p-value = 0.0546, critical value = 0.0029
# Rank 59: p-value = 0.0554, critical value = 0.0029
# Rank 60: p-value = 0.0559, critical value = 0.0030
# Rank 61: p-value = 0.0561, critical value = 0.0031
# Rank 62: p-value = 0.0562, critical value = 0.0031
# Rank 63: p-value = 0.0577, critical value = 0.0032
# Rank 64: p-value = 0.0591, critical value = 0.0032
# Rank 65: p-value = 0.0600, critical value = 0.0033
# Rank 66: p-value = 0.0615, critical value = 0.0033
# Rank 67: p-value = 0.0620, critical value = 0.0034
# Rank 68: p-value = 0.0628, critical value = 0.0034
# Rank 69: p-value = 0.0629, critical value = 0.0035
# Rank 70: p-value = 0.0632, critical value = 0.0035
# Rank 71: p-value = 0.0652, critical value = 0.0035
# Rank 72: p-value = 0.0660, critical value = 0.0036
# Rank 73: p-value = 0.0676, critical value = 0.0037
# Rank 74: p-value = 0.0680, critical value = 0.0037
# Rank 75: p-value = 0.0703, critical value = 0.0037
# Rank 76: p-value = 0.0709, critical value = 0.0038
# Rank 77: p-value = 0.0710, critical value = 0.0039
# Rank 78: p-value = 0.0716, critical value = 0.0039
# Rank 79: p-value = 0.0744, critical value = 0.0040
# Rank 80: p-value = 0.0744, critical value = 0.0040
# Rank 81: p-value = 0.0745, critical value = 0.0041
# Rank 82: p-value = 0.0758, critical value = 0.0041
# Rank 83: p-value = 0.0759, critical value = 0.0042
# Rank 84: p-value = 0.0765, critical value = 0.0042
# Rank 85: p-value = 0.0776, critical value = 0.0043
# Rank 86: p-value = 0.0783, critical value = 0.0043
# Rank 87: p-value = 0.0785, critical value = 0.0043
# Rank 88: p-value = 0.0814, critical value = 0.0044
# Rank 89: p-value = 0.0826, critical value = 0.0044
# Rank 90: p-value = 0.0852, critical value = 0.0045
# Rank 91: p-value = 0.0859, critical value = 0.0046
# Rank 92: p-value = 0.0900, critical value = 0.0046
# Rank 93: p-value = 0.0905, critical value = 0.0047
# Rank 94: p-value = 0.0910, critical value = 0.0047
# Rank 95: p-value = 0.0910, critical value = 0.0048
# Rank 96: p-value = 0.0925, critical value = 0.0048
# Rank 97: p-value = 0.0925, critical value = 0.0049
# Rank 98: p-value = 0.0926, critical value = 0.0049
# Rank 99: p-value = 0.0929, critical value = 0.0050
# Rank 100: p-value = 0.0931, critical value = 0.0050
# Rank 101: p-value = 0.0949, critical value = 0.0051
# Rank 102: p-value = 0.0952, critical value = 0.0051
# Rank 103: p-value = 0.0956, critical value = 0.0052
# Rank 104: p-value = 0.0966, critical value = 0.0052
# Rank 105: p-value = 0.0972, critical value = 0.0053
# Rank 106: p-value = 0.0974, critical value = 0.0053
# Rank 107: p-value = 0.0978, critical value = 0.0054
# Rank 108: p-value = 0.0978, critical value = 0.0054
# Rank 109: p-value = 0.0978, critical value = 0.0054
# Rank 110: p-value = 0.0984, critical value = 0.0055
# Rank 111: p-value = 0.0994, critical value = 0.0056
# Rank 112: p-value = 0.0995, critical value = 0.0056
# Rank 113: p-value = 0.1017, critical value = 0.0057
# Rank 114: p-value = 0.1017, critical value = 0.0057
# Rank 115: p-value = 0.1030, critical value = 0.0058
# Rank 116: p-value = 0.1040, critical value = 0.0058
# Rank 117: p-value = 0.1061, critical value = 0.0059
# Rank 118: p-value = 0.1077, critical value = 0.0059
# Rank 119: p-value = 0.1079, critical value = 0.0060
# Rank 120: p-value = 0.1088, critical value = 0.0060
# Rank 121: p-value = 0.1104, critical value = 0.0060
# Rank 122: p-value = 0.1119, critical value = 0.0061
# Rank 123: p-value = 0.1128, critical value = 0.0062
# Rank 124: p-value = 0.1134, critical value = 0.0062
# Rank 125: p-value = 0.1177, critical value = 0.0063
# Rank 126: p-value = 0.1181, critical value = 0.0063
# Rank 127: p-value = 0.1184, critical value = 0.0064
# Rank 128: p-value = 0.1190, critical value = 0.0064
# Rank 129: p-value = 0.1192, critical value = 0.0065
# Rank 130: p-value = 0.1192, critical value = 0.0065
# Rank 131: p-value = 0.1205, critical value = 0.0066
# Rank 132: p-value = 0.1209, critical value = 0.0066
# Rank 133: p-value = 0.1210, critical value = 0.0067
# Rank 134: p-value = 0.1210, critical value = 0.0067
# Rank 135: p-value = 0.1221, critical value = 0.0068
# Rank 136: p-value = 0.1221, critical value = 0.0068
# Rank 137: p-value = 0.1227, critical value = 0.0069
# Rank 138: p-value = 0.1232, critical value = 0.0069
# Rank 139: p-value = 0.1252, critical value = 0.0070
# Rank 140: p-value = 0.1272, critical value = 0.0070
# Rank 141: p-value = 0.1274, critical value = 0.0070
# Rank 142: p-value = 0.1297, critical value = 0.0071
# Rank 143: p-value = 0.1304, critical value = 0.0072
# Rank 144: p-value = 0.1351, critical value = 0.0072
# Rank 145: p-value = 0.1355, critical value = 0.0072
# Rank 146: p-value = 0.1379, critical value = 0.0073
# Rank 147: p-value = 0.1385, critical value = 0.0073
# Rank 148: p-value = 0.1386, critical value = 0.0074
# Rank 149: p-value = 0.1410, critical value = 0.0075
# Rank 150: p-value = 0.1431, critical value = 0.0075
# Rank 151: p-value = 0.1442, critical value = 0.0076
# Rank 152: p-value = 0.1452, critical value = 0.0076
# Rank 153: p-value = 0.1470, critical value = 0.0077
# Rank 154: p-value = 0.1472, critical value = 0.0077
# Rank 155: p-value = 0.1480, critical value = 0.0077
# Rank 156: p-value = 0.1489, critical value = 0.0078
# Rank 157: p-value = 0.1490, critical value = 0.0079
# Rank 158: p-value = 0.1498, critical value = 0.0079
# Rank 159: p-value = 0.1498, critical value = 0.0080
# Rank 160: p-value = 0.1512, critical value = 0.0080
# Rank 161: p-value = 0.1520, critical value = 0.0080
# Rank 162: p-value = 0.1525, critical value = 0.0081
# Rank 163: p-value = 0.1528, critical value = 0.0082
# Rank 164: p-value = 0.1531, critical value = 0.0082
# Rank 165: p-value = 0.1535, critical value = 0.0083
# Rank 166: p-value = 0.1535, critical value = 0.0083
# Rank 167: p-value = 0.1537, critical value = 0.0084
# Rank 168: p-value = 0.1538, critical value = 0.0084
# Rank 169: p-value = 0.1562, critical value = 0.0085
# Rank 170: p-value = 0.1564, critical value = 0.0085
# Rank 171: p-value = 0.1568, critical value = 0.0086
# Rank 172: p-value = 0.1586, critical value = 0.0086
# Rank 173: p-value = 0.1588, critical value = 0.0086
# Rank 174: p-value = 0.1594, critical value = 0.0087
# Rank 175: p-value = 0.1596, critical value = 0.0087
# Rank 176: p-value = 0.1596, critical value = 0.0088
# Rank 177: p-value = 0.1611, critical value = 0.0089
# Rank 178: p-value = 0.1626, critical value = 0.0089
# Rank 179: p-value = 0.1633, critical value = 0.0089
# Rank 180: p-value = 0.1645, critical value = 0.0090
# Rank 181: p-value = 0.1648, critical value = 0.0091
# Rank 182: p-value = 0.1663, critical value = 0.0091
# Rank 183: p-value = 0.1673, critical value = 0.0092
# Rank 184: p-value = 0.1679, critical value = 0.0092
# Rank 185: p-value = 0.1684, critical value = 0.0092
# Rank 186: p-value = 0.1707, critical value = 0.0093
# Rank 187: p-value = 0.1764, critical value = 0.0094
# Rank 188: p-value = 0.1765, critical value = 0.0094
# Rank 189: p-value = 0.1785, critical value = 0.0095
# Rank 190: p-value = 0.1829, critical value = 0.0095
# Rank 191: p-value = 0.1841, critical value = 0.0096
# Rank 192: p-value = 0.1864, critical value = 0.0096
# Rank 193: p-value = 0.1888, critical value = 0.0097
# Rank 194: p-value = 0.1892, critical value = 0.0097
# Rank 195: p-value = 0.1907, critical value = 0.0098
# Rank 196: p-value = 0.1920, critical value = 0.0098
# Rank 197: p-value = 0.1923, critical value = 0.0099
# Rank 198: p-value = 0.1935, critical value = 0.0099
# Rank 199: p-value = 0.1953, critical value = 0.0100
# Rank 200: p-value = 0.1955, critical value = 0.0100
# Rank 201: p-value = 0.1960, critical value = 0.0101
# Rank 202: p-value = 0.1964, critical value = 0.0101
# Rank 203: p-value = 0.1967, critical value = 0.0102
# Rank 204: p-value = 0.1984, critical value = 0.0102
# Rank 205: p-value = 0.1986, critical value = 0.0103
# Rank 206: p-value = 0.1987, critical value = 0.0103
# Rank 207: p-value = 0.2014, critical value = 0.0103
# Rank 208: p-value = 0.2024, critical value = 0.0104
# Rank 209: p-value = 0.2031, critical value = 0.0105
# Rank 210: p-value = 0.2041, critical value = 0.0105
# Rank 211: p-value = 0.2055, critical value = 0.0106
# Rank 212: p-value = 0.2055, critical value = 0.0106
# Rank 213: p-value = 0.2056, critical value = 0.0106
# Rank 214: p-value = 0.2065, critical value = 0.0107
# Rank 215: p-value = 0.2073, critical value = 0.0108
# Rank 216: p-value = 0.2074, critical value = 0.0108
# Rank 217: p-value = 0.2087, critical value = 0.0109
# Rank 218: p-value = 0.2096, critical value = 0.0109
# Rank 219: p-value = 0.2106, critical value = 0.0110
# Rank 220: p-value = 0.2112, critical value = 0.0110
# Rank 221: p-value = 0.2131, critical value = 0.0111
# Rank 222: p-value = 0.2169, critical value = 0.0111
# Rank 223: p-value = 0.2170, critical value = 0.0112
# Rank 224: p-value = 0.2175, critical value = 0.0112
# Rank 225: p-value = 0.2191, critical value = 0.0113
# Rank 226: p-value = 0.2229, critical value = 0.0113
# Rank 227: p-value = 0.2235, critical value = 0.0114
# Rank 228: p-value = 0.2244, critical value = 0.0114
# Rank 229: p-value = 0.2254, critical value = 0.0115
# Rank 230: p-value = 0.2261, critical value = 0.0115
# Rank 231: p-value = 0.2274, critical value = 0.0116
# Rank 232: p-value = 0.2277, critical value = 0.0116
# Rank 233: p-value = 0.2320, critical value = 0.0117
# Rank 234: p-value = 0.2350, critical value = 0.0117
# Rank 235: p-value = 0.2355, critical value = 0.0118
# Rank 236: p-value = 0.2358, critical value = 0.0118
# Rank 237: p-value = 0.2363, critical value = 0.0118
# Rank 238: p-value = 0.2364, critical value = 0.0119
# Rank 239: p-value = 0.2413, critical value = 0.0120
# Rank 240: p-value = 0.2427, critical value = 0.0120
# Rank 241: p-value = 0.2439, critical value = 0.0120
# Rank 242: p-value = 0.2449, critical value = 0.0121
# Rank 243: p-value = 0.2455, critical value = 0.0122
# Rank 244: p-value = 0.2456, critical value = 0.0122
# Rank 245: p-value = 0.2468, critical value = 0.0123
# Rank 246: p-value = 0.2471, critical value = 0.0123
# Rank 247: p-value = 0.2477, critical value = 0.0123
# Rank 248: p-value = 0.2495, critical value = 0.0124
# Rank 249: p-value = 0.2512, critical value = 0.0125
# Rank 250: p-value = 0.2537, critical value = 0.0125
# Rank 251: p-value = 0.2546, critical value = 0.0126
# Rank 252: p-value = 0.2547, critical value = 0.0126
# Rank 253: p-value = 0.2550, critical value = 0.0127
# Rank 254: p-value = 0.2551, critical value = 0.0127
# Rank 255: p-value = 0.2553, critical value = 0.0128
# Rank 256: p-value = 0.2558, critical value = 0.0128
# Rank 257: p-value = 0.2559, critical value = 0.0129
# Rank 258: p-value = 0.2559, critical value = 0.0129
# Rank 259: p-value = 0.2562, critical value = 0.0130
# Rank 260: p-value = 0.2569, critical value = 0.0130
# Rank 261: p-value = 0.2574, critical value = 0.0131
# Rank 262: p-value = 0.2594, critical value = 0.0131
# Rank 263: p-value = 0.2615, critical value = 0.0132
# Rank 264: p-value = 0.2618, critical value = 0.0132
# Rank 265: p-value = 0.2631, critical value = 0.0133
# Rank 266: p-value = 0.2633, critical value = 0.0133
# Rank 267: p-value = 0.2641, critical value = 0.0134
# Rank 268: p-value = 0.2668, critical value = 0.0134
# Rank 269: p-value = 0.2670, critical value = 0.0135
# Rank 270: p-value = 0.2675, critical value = 0.0135
# Rank 271: p-value = 0.2695, critical value = 0.0136
# Rank 272: p-value = 0.2702, critical value = 0.0136
# Rank 273: p-value = 0.2712, critical value = 0.0137
# Rank 274: p-value = 0.2729, critical value = 0.0137
# Rank 275: p-value = 0.2730, critical value = 0.0138
# Rank 276: p-value = 0.2734, critical value = 0.0138
# Rank 277: p-value = 0.2753, critical value = 0.0139
# Rank 278: p-value = 0.2767, critical value = 0.0139
# Rank 279: p-value = 0.2773, critical value = 0.0140
# Rank 280: p-value = 0.2794, critical value = 0.0140
# Rank 281: p-value = 0.2810, critical value = 0.0141
# Rank 282: p-value = 0.2818, critical value = 0.0141
# Rank 283: p-value = 0.2849, critical value = 0.0141
# Rank 284: p-value = 0.2903, critical value = 0.0142
# Rank 285: p-value = 0.2919, critical value = 0.0142
# Rank 286: p-value = 0.2923, critical value = 0.0143
# Rank 287: p-value = 0.2932, critical value = 0.0143
# Rank 288: p-value = 0.2944, critical value = 0.0144
# Rank 289: p-value = 0.2945, critical value = 0.0144
# Rank 290: p-value = 0.2955, critical value = 0.0145
# Rank 291: p-value = 0.2956, critical value = 0.0146
# Rank 292: p-value = 0.2957, critical value = 0.0146
# Rank 293: p-value = 0.2963, critical value = 0.0146
# Rank 294: p-value = 0.2966, critical value = 0.0147
# Rank 295: p-value = 0.2975, critical value = 0.0147
# Rank 296: p-value = 0.2988, critical value = 0.0148
# Rank 297: p-value = 0.2993, critical value = 0.0149
# Rank 298: p-value = 0.3012, critical value = 0.0149
# Rank 299: p-value = 0.3013, critical value = 0.0149
# Rank 300: p-value = 0.3015, critical value = 0.0150
# Rank 301: p-value = 0.3034, critical value = 0.0151
# Rank 302: p-value = 0.3035, critical value = 0.0151
# Rank 303: p-value = 0.3041, critical value = 0.0152
# Rank 304: p-value = 0.3049, critical value = 0.0152
# Rank 305: p-value = 0.3049, critical value = 0.0152
# Rank 306: p-value = 0.3082, critical value = 0.0153
# Rank 307: p-value = 0.3096, critical value = 0.0154
# Rank 308: p-value = 0.3097, critical value = 0.0154
# Rank 309: p-value = 0.3127, critical value = 0.0155
# Rank 310: p-value = 0.3136, critical value = 0.0155
# Rank 311: p-value = 0.3157, critical value = 0.0156
# Rank 312: p-value = 0.3158, critical value = 0.0156
# Rank 313: p-value = 0.3159, critical value = 0.0157
# Rank 314: p-value = 0.3160, critical value = 0.0157
# Rank 315: p-value = 0.3161, critical value = 0.0158
# Rank 316: p-value = 0.3166, critical value = 0.0158
# Rank 317: p-value = 0.3174, critical value = 0.0158
# Rank 318: p-value = 0.3179, critical value = 0.0159
# Rank 319: p-value = 0.3185, critical value = 0.0160
# Rank 320: p-value = 0.3187, critical value = 0.0160
# Rank 321: p-value = 0.3189, critical value = 0.0161
# Rank 322: p-value = 0.3197, critical value = 0.0161
# Rank 323: p-value = 0.3211, critical value = 0.0162
# Rank 324: p-value = 0.3213, critical value = 0.0162
# Rank 325: p-value = 0.3220, critical value = 0.0163
# Rank 326: p-value = 0.3225, critical value = 0.0163
# Rank 327: p-value = 0.3229, critical value = 0.0163
# Rank 328: p-value = 0.3246, critical value = 0.0164
# Rank 329: p-value = 0.3264, critical value = 0.0165
# Rank 330: p-value = 0.3287, critical value = 0.0165
# Rank 331: p-value = 0.3301, critical value = 0.0166
# Rank 332: p-value = 0.3316, critical value = 0.0166
# Rank 333: p-value = 0.3319, critical value = 0.0167
# Rank 334: p-value = 0.3328, critical value = 0.0167
# Rank 335: p-value = 0.3339, critical value = 0.0168
# Rank 336: p-value = 0.3340, critical value = 0.0168
# Rank 337: p-value = 0.3358, critical value = 0.0169
# Rank 338: p-value = 0.3358, critical value = 0.0169
# Rank 339: p-value = 0.3359, critical value = 0.0170
# Rank 340: p-value = 0.3366, critical value = 0.0170
# Rank 341: p-value = 0.3374, critical value = 0.0171
# Rank 342: p-value = 0.3376, critical value = 0.0171
# Rank 343: p-value = 0.3380, critical value = 0.0172
# Rank 344: p-value = 0.3391, critical value = 0.0172
# Rank 345: p-value = 0.3392, critical value = 0.0172
# Rank 346: p-value = 0.3398, critical value = 0.0173
# Rank 347: p-value = 0.3418, critical value = 0.0174
# Rank 348: p-value = 0.3429, critical value = 0.0174
# Rank 349: p-value = 0.3436, critical value = 0.0175
# Rank 350: p-value = 0.3442, critical value = 0.0175
# Rank 351: p-value = 0.3458, critical value = 0.0175
# Rank 352: p-value = 0.3464, critical value = 0.0176
# Rank 353: p-value = 0.3465, critical value = 0.0176
# Rank 354: p-value = 0.3472, critical value = 0.0177
# Rank 355: p-value = 0.3480, critical value = 0.0177
# Rank 356: p-value = 0.3518, critical value = 0.0178
# Rank 357: p-value = 0.3524, critical value = 0.0179
# Rank 358: p-value = 0.3526, critical value = 0.0179
# Rank 359: p-value = 0.3529, critical value = 0.0180
# Rank 360: p-value = 0.3549, critical value = 0.0180
# Rank 361: p-value = 0.3551, critical value = 0.0181
# Rank 362: p-value = 0.3553, critical value = 0.0181
# Rank 363: p-value = 0.3563, critical value = 0.0181
# Rank 364: p-value = 0.3565, critical value = 0.0182
# Rank 365: p-value = 0.3570, critical value = 0.0182
# Rank 366: p-value = 0.3570, critical value = 0.0183
# Rank 367: p-value = 0.3577, critical value = 0.0184
# Rank 368: p-value = 0.3606, critical value = 0.0184
# Rank 369: p-value = 0.3613, critical value = 0.0185
# Rank 370: p-value = 0.3615, critical value = 0.0185
# Rank 371: p-value = 0.3623, critical value = 0.0186
# Rank 372: p-value = 0.3624, critical value = 0.0186
# Rank 373: p-value = 0.3636, critical value = 0.0186
# Rank 374: p-value = 0.3653, critical value = 0.0187
# Rank 375: p-value = 0.3656, critical value = 0.0188
# Rank 376: p-value = 0.3665, critical value = 0.0188
# Rank 377: p-value = 0.3665, critical value = 0.0189
# Rank 378: p-value = 0.3680, critical value = 0.0189
# Rank 379: p-value = 0.3681, critical value = 0.0190
# Rank 380: p-value = 0.3687, critical value = 0.0190
# Rank 381: p-value = 0.3697, critical value = 0.0191
# Rank 382: p-value = 0.3714, critical value = 0.0191
# Rank 383: p-value = 0.3719, critical value = 0.0192
# Rank 384: p-value = 0.3721, critical value = 0.0192
# Rank 385: p-value = 0.3727, critical value = 0.0193
# Rank 386: p-value = 0.3745, critical value = 0.0193
# Rank 387: p-value = 0.3782, critical value = 0.0194
# Rank 388: p-value = 0.3785, critical value = 0.0194
# Rank 389: p-value = 0.3790, critical value = 0.0195
# Rank 390: p-value = 0.3852, critical value = 0.0195
# Rank 391: p-value = 0.3860, critical value = 0.0196
# Rank 392: p-value = 0.3868, critical value = 0.0196
# Rank 393: p-value = 0.3877, critical value = 0.0197
# Rank 394: p-value = 0.3877, critical value = 0.0197
# Rank 395: p-value = 0.3879, critical value = 0.0198
# Rank 396: p-value = 0.3884, critical value = 0.0198
# Rank 397: p-value = 0.3901, critical value = 0.0199
# Rank 398: p-value = 0.3902, critical value = 0.0199
# Rank 399: p-value = 0.3937, critical value = 0.0200
# Rank 400: p-value = 0.3943, critical value = 0.0200
# Rank 401: p-value = 0.3957, critical value = 0.0201
# Rank 402: p-value = 0.3966, critical value = 0.0201
# Rank 403: p-value = 0.3981, critical value = 0.0202
# Rank 404: p-value = 0.3981, critical value = 0.0202
# Rank 405: p-value = 0.3983, critical value = 0.0203
# Rank 406: p-value = 0.3987, critical value = 0.0203
# Rank 407: p-value = 0.3994, critical value = 0.0204
# Rank 408: p-value = 0.3994, critical value = 0.0204
# Rank 409: p-value = 0.4012, critical value = 0.0204
# Rank 410: p-value = 0.4020, critical value = 0.0205
# Rank 411: p-value = 0.4020, critical value = 0.0205
# Rank 412: p-value = 0.4025, critical value = 0.0206
# Rank 413: p-value = 0.4028, critical value = 0.0207
# Rank 414: p-value = 0.4035, critical value = 0.0207
# Rank 415: p-value = 0.4074, critical value = 0.0208
# Rank 416: p-value = 0.4084, critical value = 0.0208
# Rank 417: p-value = 0.4123, critical value = 0.0209
# Rank 418: p-value = 0.4126, critical value = 0.0209
# Rank 419: p-value = 0.4127, critical value = 0.0209
# Rank 420: p-value = 0.4140, critical value = 0.0210
# Rank 421: p-value = 0.4168, critical value = 0.0210
# Rank 422: p-value = 0.4202, critical value = 0.0211
# Rank 423: p-value = 0.4207, critical value = 0.0212
# Rank 424: p-value = 0.4250, critical value = 0.0212
# Rank 425: p-value = 0.4257, critical value = 0.0213
# Rank 426: p-value = 0.4265, critical value = 0.0213
# Rank 427: p-value = 0.4275, critical value = 0.0214
# Rank 428: p-value = 0.4281, critical value = 0.0214
# Rank 429: p-value = 0.4286, critical value = 0.0215
# Rank 430: p-value = 0.4294, critical value = 0.0215
# Rank 431: p-value = 0.4297, critical value = 0.0215
# Rank 432: p-value = 0.4311, critical value = 0.0216
# Rank 433: p-value = 0.4322, critical value = 0.0217
# Rank 434: p-value = 0.4327, critical value = 0.0217
# Rank 435: p-value = 0.4348, critical value = 0.0218
# Rank 436: p-value = 0.4351, critical value = 0.0218
# Rank 437: p-value = 0.4351, critical value = 0.0219
# Rank 438: p-value = 0.4356, critical value = 0.0219
# Rank 439: p-value = 0.4363, critical value = 0.0220
# Rank 440: p-value = 0.4382, critical value = 0.0220
# Rank 441: p-value = 0.4394, critical value = 0.0221
# Rank 442: p-value = 0.4394, critical value = 0.0221
# Rank 443: p-value = 0.4403, critical value = 0.0222
# Rank 444: p-value = 0.4405, critical value = 0.0222
# Rank 445: p-value = 0.4420, critical value = 0.0223
# Rank 446: p-value = 0.4428, critical value = 0.0223
# Rank 447: p-value = 0.4432, critical value = 0.0224
# Rank 448: p-value = 0.4447, critical value = 0.0224
# Rank 449: p-value = 0.4459, critical value = 0.0225
# Rank 450: p-value = 0.4470, critical value = 0.0225
# Rank 451: p-value = 0.4484, critical value = 0.0226
# Rank 452: p-value = 0.4486, critical value = 0.0226
# Rank 453: p-value = 0.4494, critical value = 0.0227
# Rank 454: p-value = 0.4498, critical value = 0.0227
# Rank 455: p-value = 0.4505, critical value = 0.0228
# Rank 456: p-value = 0.4507, critical value = 0.0228
# Rank 457: p-value = 0.4515, critical value = 0.0229
# Rank 458: p-value = 0.4529, critical value = 0.0229
# Rank 459: p-value = 0.4551, critical value = 0.0230
# Rank 460: p-value = 0.4559, critical value = 0.0230
# Rank 461: p-value = 0.4567, critical value = 0.0231
# Rank 462: p-value = 0.4575, critical value = 0.0231
# Rank 463: p-value = 0.4590, critical value = 0.0232
# Rank 464: p-value = 0.4599, critical value = 0.0232
# Rank 465: p-value = 0.4613, critical value = 0.0233
# Rank 466: p-value = 0.4646, critical value = 0.0233
# Rank 467: p-value = 0.4654, critical value = 0.0234
# Rank 468: p-value = 0.4699, critical value = 0.0234
# Rank 469: p-value = 0.4704, critical value = 0.0234
# Rank 470: p-value = 0.4704, critical value = 0.0235
# Rank 471: p-value = 0.4705, critical value = 0.0236
# Rank 472: p-value = 0.4728, critical value = 0.0236
# Rank 473: p-value = 0.4728, critical value = 0.0237
# Rank 474: p-value = 0.4740, critical value = 0.0237
# Rank 475: p-value = 0.4753, critical value = 0.0238
# Rank 476: p-value = 0.4768, critical value = 0.0238
# Rank 477: p-value = 0.4790, critical value = 0.0238
# Rank 478: p-value = 0.4809, critical value = 0.0239
# Rank 479: p-value = 0.4818, critical value = 0.0239
# Rank 480: p-value = 0.4819, critical value = 0.0240
# Rank 481: p-value = 0.4861, critical value = 0.0241
# Rank 482: p-value = 0.4872, critical value = 0.0241
# Rank 483: p-value = 0.4879, critical value = 0.0242
# Rank 484: p-value = 0.4883, critical value = 0.0242
# Rank 485: p-value = 0.4885, critical value = 0.0243
# Rank 486: p-value = 0.4889, critical value = 0.0243
# Rank 487: p-value = 0.4921, critical value = 0.0244
# Rank 488: p-value = 0.4924, critical value = 0.0244
# Rank 489: p-value = 0.4934, critical value = 0.0244
# Rank 490: p-value = 0.4952, critical value = 0.0245
# Rank 491: p-value = 0.4969, critical value = 0.0246
# Rank 492: p-value = 0.4970, critical value = 0.0246
# Rank 493: p-value = 0.4971, critical value = 0.0247
# Rank 494: p-value = 0.4972, critical value = 0.0247
# Rank 495: p-value = 0.4977, critical value = 0.0248
# Rank 496: p-value = 0.4979, critical value = 0.0248
# Rank 497: p-value = 0.5002, critical value = 0.0249
# Rank 498: p-value = 0.5005, critical value = 0.0249
# Rank 499: p-value = 0.5010, critical value = 0.0249
# Rank 500: p-value = 0.5019, critical value = 0.0250
# Rank 501: p-value = 0.5020, critical value = 0.0251
# Rank 502: p-value = 0.5035, critical value = 0.0251
# Rank 503: p-value = 0.5056, critical value = 0.0252
# Rank 504: p-value = 0.5059, critical value = 0.0252
# Rank 505: p-value = 0.5076, critical value = 0.0253
# Rank 506: p-value = 0.5076, critical value = 0.0253
# Rank 507: p-value = 0.5085, critical value = 0.0254
# Rank 508: p-value = 0.5089, critical value = 0.0254
# Rank 509: p-value = 0.5108, critical value = 0.0255
# Rank 510: p-value = 0.5110, critical value = 0.0255
# Rank 511: p-value = 0.5160, critical value = 0.0256
# Rank 512: p-value = 0.5189, critical value = 0.0256
# Rank 513: p-value = 0.5193, critical value = 0.0257
# Rank 514: p-value = 0.5210, critical value = 0.0257
# Rank 515: p-value = 0.5216, critical value = 0.0258
# Rank 516: p-value = 0.5219, critical value = 0.0258
# Rank 517: p-value = 0.5220, critical value = 0.0259
# Rank 518: p-value = 0.5224, critical value = 0.0259
# Rank 519: p-value = 0.5246, critical value = 0.0260
# Rank 520: p-value = 0.5246, critical value = 0.0260
# Rank 521: p-value = 0.5249, critical value = 0.0261
# Rank 522: p-value = 0.5258, critical value = 0.0261
# Rank 523: p-value = 0.5295, critical value = 0.0262
# Rank 524: p-value = 0.5296, critical value = 0.0262
# Rank 525: p-value = 0.5312, critical value = 0.0263
# Rank 526: p-value = 0.5326, critical value = 0.0263
# Rank 527: p-value = 0.5327, critical value = 0.0264
# Rank 528: p-value = 0.5334, critical value = 0.0264
# Rank 529: p-value = 0.5344, critical value = 0.0265
# Rank 530: p-value = 0.5347, critical value = 0.0265
# Rank 531: p-value = 0.5361, critical value = 0.0266
# Rank 532: p-value = 0.5363, critical value = 0.0266
# Rank 533: p-value = 0.5367, critical value = 0.0267
# Rank 534: p-value = 0.5368, critical value = 0.0267
# Rank 535: p-value = 0.5432, critical value = 0.0268
# Rank 536: p-value = 0.5450, critical value = 0.0268
# Rank 537: p-value = 0.5465, critical value = 0.0269
# Rank 538: p-value = 0.5485, critical value = 0.0269
# Rank 539: p-value = 0.5488, critical value = 0.0270
# Rank 540: p-value = 0.5508, critical value = 0.0270
# Rank 541: p-value = 0.5520, critical value = 0.0271
# Rank 542: p-value = 0.5525, critical value = 0.0271
# Rank 543: p-value = 0.5529, critical value = 0.0272
# Rank 544: p-value = 0.5551, critical value = 0.0272
# Rank 545: p-value = 0.5553, critical value = 0.0273
# Rank 546: p-value = 0.5559, critical value = 0.0273
# Rank 547: p-value = 0.5564, critical value = 0.0274
# Rank 548: p-value = 0.5566, critical value = 0.0274
# Rank 549: p-value = 0.5569, critical value = 0.0275
# Rank 550: p-value = 0.5585, critical value = 0.0275
# Rank 551: p-value = 0.5602, critical value = 0.0276
# Rank 552: p-value = 0.5606, critical value = 0.0276
# Rank 553: p-value = 0.5631, critical value = 0.0277
# Rank 554: p-value = 0.5633, critical value = 0.0277
# Rank 555: p-value = 0.5651, critical value = 0.0278
# Rank 556: p-value = 0.5680, critical value = 0.0278
# Rank 557: p-value = 0.5688, critical value = 0.0279
# Rank 558: p-value = 0.5690, critical value = 0.0279
# Rank 559: p-value = 0.5691, critical value = 0.0280
# Rank 560: p-value = 0.5706, critical value = 0.0280
# Rank 561: p-value = 0.5711, critical value = 0.0281
# Rank 562: p-value = 0.5732, critical value = 0.0281
# Rank 563: p-value = 0.5748, critical value = 0.0281
# Rank 564: p-value = 0.5751, critical value = 0.0282
# Rank 565: p-value = 0.5751, critical value = 0.0282
# Rank 566: p-value = 0.5752, critical value = 0.0283
# Rank 567: p-value = 0.5754, critical value = 0.0284
# Rank 568: p-value = 0.5774, critical value = 0.0284
# Rank 569: p-value = 0.5777, critical value = 0.0284
# Rank 570: p-value = 0.5809, critical value = 0.0285
# Rank 571: p-value = 0.5817, critical value = 0.0285
# Rank 572: p-value = 0.5826, critical value = 0.0286
# Rank 573: p-value = 0.5827, critical value = 0.0286
# Rank 574: p-value = 0.5829, critical value = 0.0287
# Rank 575: p-value = 0.5844, critical value = 0.0287
# Rank 576: p-value = 0.5848, critical value = 0.0288
# Rank 577: p-value = 0.5863, critical value = 0.0289
# Rank 578: p-value = 0.5863, critical value = 0.0289
# Rank 579: p-value = 0.5867, critical value = 0.0290
# Rank 580: p-value = 0.5875, critical value = 0.0290
# Rank 581: p-value = 0.5888, critical value = 0.0290
# Rank 582: p-value = 0.5903, critical value = 0.0291
# Rank 583: p-value = 0.5904, critical value = 0.0291
# Rank 584: p-value = 0.5904, critical value = 0.0292
# Rank 585: p-value = 0.5917, critical value = 0.0292
# Rank 586: p-value = 0.5918, critical value = 0.0293
# Rank 587: p-value = 0.5922, critical value = 0.0294
# Rank 588: p-value = 0.5950, critical value = 0.0294
# Rank 589: p-value = 0.5992, critical value = 0.0295
# Rank 590: p-value = 0.6000, critical value = 0.0295
# Rank 591: p-value = 0.6013, critical value = 0.0295
# Rank 592: p-value = 0.6031, critical value = 0.0296
# Rank 593: p-value = 0.6053, critical value = 0.0296
# Rank 594: p-value = 0.6062, critical value = 0.0297
# Rank 595: p-value = 0.6085, critical value = 0.0297
# Rank 596: p-value = 0.6095, critical value = 0.0298
# Rank 597: p-value = 0.6096, critical value = 0.0299
# Rank 598: p-value = 0.6101, critical value = 0.0299
# Rank 599: p-value = 0.6105, critical value = 0.0300
# Rank 600: p-value = 0.6131, critical value = 0.0300
# Rank 601: p-value = 0.6138, critical value = 0.0301
# Rank 602: p-value = 0.6151, critical value = 0.0301
# Rank 603: p-value = 0.6163, critical value = 0.0301
# Rank 604: p-value = 0.6174, critical value = 0.0302
# Rank 605: p-value = 0.6185, critical value = 0.0302
# Rank 606: p-value = 0.6198, critical value = 0.0303
# Rank 607: p-value = 0.6207, critical value = 0.0304
# Rank 608: p-value = 0.6215, critical value = 0.0304
# Rank 609: p-value = 0.6221, critical value = 0.0305
# Rank 610: p-value = 0.6224, critical value = 0.0305
# Rank 611: p-value = 0.6226, critical value = 0.0306
# Rank 612: p-value = 0.6243, critical value = 0.0306
# Rank 613: p-value = 0.6278, critical value = 0.0307
# Rank 614: p-value = 0.6283, critical value = 0.0307
# Rank 615: p-value = 0.6299, critical value = 0.0307
# Rank 616: p-value = 0.6302, critical value = 0.0308
# Rank 617: p-value = 0.6309, critical value = 0.0309
# Rank 618: p-value = 0.6331, critical value = 0.0309
# Rank 619: p-value = 0.6333, critical value = 0.0310
# Rank 620: p-value = 0.6334, critical value = 0.0310
# Rank 621: p-value = 0.6335, critical value = 0.0311
# Rank 622: p-value = 0.6342, critical value = 0.0311
# Rank 623: p-value = 0.6345, critical value = 0.0312
# Rank 624: p-value = 0.6358, critical value = 0.0312
# Rank 625: p-value = 0.6364, critical value = 0.0312
# Rank 626: p-value = 0.6369, critical value = 0.0313
# Rank 627: p-value = 0.6369, critical value = 0.0314
# Rank 628: p-value = 0.6378, critical value = 0.0314
# Rank 629: p-value = 0.6387, critical value = 0.0314
# Rank 630: p-value = 0.6393, critical value = 0.0315
# Rank 631: p-value = 0.6407, critical value = 0.0316
# Rank 632: p-value = 0.6409, critical value = 0.0316
# Rank 633: p-value = 0.6431, critical value = 0.0317
# Rank 634: p-value = 0.6432, critical value = 0.0317
# Rank 635: p-value = 0.6449, critical value = 0.0318
# Rank 636: p-value = 0.6452, critical value = 0.0318
# Rank 637: p-value = 0.6461, critical value = 0.0319
# Rank 638: p-value = 0.6470, critical value = 0.0319
# Rank 639: p-value = 0.6473, critical value = 0.0319
# Rank 640: p-value = 0.6477, critical value = 0.0320
# Rank 641: p-value = 0.6495, critical value = 0.0321
# Rank 642: p-value = 0.6511, critical value = 0.0321
# Rank 643: p-value = 0.6527, critical value = 0.0322
# Rank 644: p-value = 0.6542, critical value = 0.0322
# Rank 645: p-value = 0.6545, critical value = 0.0323
# Rank 646: p-value = 0.6575, critical value = 0.0323
# Rank 647: p-value = 0.6593, critical value = 0.0324
# Rank 648: p-value = 0.6598, critical value = 0.0324
# Rank 649: p-value = 0.6608, critical value = 0.0324
# Rank 650: p-value = 0.6610, critical value = 0.0325
# Rank 651: p-value = 0.6616, critical value = 0.0326
# Rank 652: p-value = 0.6621, critical value = 0.0326
# Rank 653: p-value = 0.6644, critical value = 0.0327
# Rank 654: p-value = 0.6655, critical value = 0.0327
# Rank 655: p-value = 0.6658, critical value = 0.0328
# Rank 656: p-value = 0.6665, critical value = 0.0328
# Rank 657: p-value = 0.6669, critical value = 0.0329
# Rank 658: p-value = 0.6681, critical value = 0.0329
# Rank 659: p-value = 0.6697, critical value = 0.0330
# Rank 660: p-value = 0.6705, critical value = 0.0330
# Rank 661: p-value = 0.6708, critical value = 0.0331
# Rank 662: p-value = 0.6709, critical value = 0.0331
# Rank 663: p-value = 0.6716, critical value = 0.0332
# Rank 664: p-value = 0.6728, critical value = 0.0332
# Rank 665: p-value = 0.6728, critical value = 0.0333
# Rank 666: p-value = 0.6729, critical value = 0.0333
# Rank 667: p-value = 0.6731, critical value = 0.0334
# Rank 668: p-value = 0.6738, critical value = 0.0334
# Rank 669: p-value = 0.6758, critical value = 0.0335
# Rank 670: p-value = 0.6759, critical value = 0.0335
# Rank 671: p-value = 0.6767, critical value = 0.0336
# Rank 672: p-value = 0.6769, critical value = 0.0336
# Rank 673: p-value = 0.6779, critical value = 0.0337
# Rank 674: p-value = 0.6784, critical value = 0.0337
# Rank 675: p-value = 0.6803, critical value = 0.0338
# Rank 676: p-value = 0.6808, critical value = 0.0338
# Rank 677: p-value = 0.6808, critical value = 0.0339
# Rank 678: p-value = 0.6815, critical value = 0.0339
# Rank 679: p-value = 0.6825, critical value = 0.0340
# Rank 680: p-value = 0.6826, critical value = 0.0340
# Rank 681: p-value = 0.6828, critical value = 0.0341
# Rank 682: p-value = 0.6835, critical value = 0.0341
# Rank 683: p-value = 0.6839, critical value = 0.0342
# Rank 684: p-value = 0.6855, critical value = 0.0342
# Rank 685: p-value = 0.6894, critical value = 0.0343
# Rank 686: p-value = 0.6909, critical value = 0.0343
# Rank 687: p-value = 0.6913, critical value = 0.0344
# Rank 688: p-value = 0.6919, critical value = 0.0344
# Rank 689: p-value = 0.6925, critical value = 0.0345
# Rank 690: p-value = 0.6930, critical value = 0.0345
# Rank 691: p-value = 0.6946, critical value = 0.0345
# Rank 692: p-value = 0.6950, critical value = 0.0346
# Rank 693: p-value = 0.6952, critical value = 0.0347
# Rank 694: p-value = 0.6963, critical value = 0.0347
# Rank 695: p-value = 0.6975, critical value = 0.0347
# Rank 696: p-value = 0.6978, critical value = 0.0348
# Rank 697: p-value = 0.7016, critical value = 0.0348
# Rank 698: p-value = 0.7032, critical value = 0.0349
# Rank 699: p-value = 0.7032, critical value = 0.0350
# Rank 700: p-value = 0.7041, critical value = 0.0350
# Rank 701: p-value = 0.7046, critical value = 0.0350
# Rank 702: p-value = 0.7053, critical value = 0.0351
# Rank 703: p-value = 0.7087, critical value = 0.0352
# Rank 704: p-value = 0.7088, critical value = 0.0352
# Rank 705: p-value = 0.7091, critical value = 0.0352
# Rank 706: p-value = 0.7091, critical value = 0.0353
# Rank 707: p-value = 0.7101, critical value = 0.0353
# Rank 708: p-value = 0.7116, critical value = 0.0354
# Rank 709: p-value = 0.7120, critical value = 0.0355
# Rank 710: p-value = 0.7121, critical value = 0.0355
# Rank 711: p-value = 0.7128, critical value = 0.0355
# Rank 712: p-value = 0.7132, critical value = 0.0356
# Rank 713: p-value = 0.7136, critical value = 0.0357
# Rank 714: p-value = 0.7139, critical value = 0.0357
# Rank 715: p-value = 0.7146, critical value = 0.0357
# Rank 716: p-value = 0.7152, critical value = 0.0358
# Rank 717: p-value = 0.7154, critical value = 0.0358
# Rank 718: p-value = 0.7166, critical value = 0.0359
# Rank 719: p-value = 0.7168, critical value = 0.0360
# Rank 720: p-value = 0.7170, critical value = 0.0360
# Rank 721: p-value = 0.7176, critical value = 0.0360
# Rank 722: p-value = 0.7179, critical value = 0.0361
# Rank 723: p-value = 0.7180, critical value = 0.0362
# Rank 724: p-value = 0.7201, critical value = 0.0362
# Rank 725: p-value = 0.7202, critical value = 0.0362
# Rank 726: p-value = 0.7207, critical value = 0.0363
# Rank 727: p-value = 0.7225, critical value = 0.0364
# Rank 728: p-value = 0.7231, critical value = 0.0364
# Rank 729: p-value = 0.7235, critical value = 0.0365
# Rank 730: p-value = 0.7250, critical value = 0.0365
# Rank 731: p-value = 0.7262, critical value = 0.0365
# Rank 732: p-value = 0.7288, critical value = 0.0366
# Rank 733: p-value = 0.7288, critical value = 0.0367
# Rank 734: p-value = 0.7297, critical value = 0.0367
# Rank 735: p-value = 0.7298, critical value = 0.0367
# Rank 736: p-value = 0.7300, critical value = 0.0368
# Rank 737: p-value = 0.7311, critical value = 0.0369
# Rank 738: p-value = 0.7314, critical value = 0.0369
# Rank 739: p-value = 0.7316, critical value = 0.0370
# Rank 740: p-value = 0.7338, critical value = 0.0370
# Rank 741: p-value = 0.7372, critical value = 0.0370
# Rank 742: p-value = 0.7376, critical value = 0.0371
# Rank 743: p-value = 0.7377, critical value = 0.0372
# Rank 744: p-value = 0.7394, critical value = 0.0372
# Rank 745: p-value = 0.7396, critical value = 0.0372
# Rank 746: p-value = 0.7441, critical value = 0.0373
# Rank 747: p-value = 0.7443, critical value = 0.0374
# Rank 748: p-value = 0.7456, critical value = 0.0374
# Rank 749: p-value = 0.7461, critical value = 0.0375
# Rank 750: p-value = 0.7488, critical value = 0.0375
# Rank 751: p-value = 0.7490, critical value = 0.0376
# Rank 752: p-value = 0.7497, critical value = 0.0376
# Rank 753: p-value = 0.7502, critical value = 0.0377
# Rank 754: p-value = 0.7506, critical value = 0.0377
# Rank 755: p-value = 0.7509, critical value = 0.0378
# Rank 756: p-value = 0.7522, critical value = 0.0378
# Rank 757: p-value = 0.7535, critical value = 0.0379
# Rank 758: p-value = 0.7537, critical value = 0.0379
# Rank 759: p-value = 0.7553, critical value = 0.0380
# Rank 760: p-value = 0.7571, critical value = 0.0380
# Rank 761: p-value = 0.7581, critical value = 0.0381
# Rank 762: p-value = 0.7582, critical value = 0.0381
# Rank 763: p-value = 0.7603, critical value = 0.0382
# Rank 764: p-value = 0.7611, critical value = 0.0382
# Rank 765: p-value = 0.7621, critical value = 0.0383
# Rank 766: p-value = 0.7623, critical value = 0.0383
# Rank 767: p-value = 0.7633, critical value = 0.0384
# Rank 768: p-value = 0.7650, critical value = 0.0384
# Rank 769: p-value = 0.7657, critical value = 0.0385
# Rank 770: p-value = 0.7661, critical value = 0.0385
# Rank 771: p-value = 0.7663, critical value = 0.0386
# Rank 772: p-value = 0.7669, critical value = 0.0386
# Rank 773: p-value = 0.7684, critical value = 0.0387
# Rank 774: p-value = 0.7699, critical value = 0.0387
# Rank 775: p-value = 0.7714, critical value = 0.0388
# Rank 776: p-value = 0.7724, critical value = 0.0388
# Rank 777: p-value = 0.7725, critical value = 0.0389
# Rank 778: p-value = 0.7746, critical value = 0.0389
# Rank 779: p-value = 0.7767, critical value = 0.0390
# Rank 780: p-value = 0.7769, critical value = 0.0390
# Rank 781: p-value = 0.7785, critical value = 0.0391
# Rank 782: p-value = 0.7788, critical value = 0.0391
# Rank 783: p-value = 0.7805, critical value = 0.0392
# Rank 784: p-value = 0.7808, critical value = 0.0392
# Rank 785: p-value = 0.7833, critical value = 0.0393
# Rank 786: p-value = 0.7843, critical value = 0.0393
# Rank 787: p-value = 0.7843, critical value = 0.0394
# Rank 788: p-value = 0.7849, critical value = 0.0394
# Rank 789: p-value = 0.7866, critical value = 0.0395
# Rank 790: p-value = 0.7880, critical value = 0.0395
# Rank 791: p-value = 0.7881, critical value = 0.0396
# Rank 792: p-value = 0.7890, critical value = 0.0396
# Rank 793: p-value = 0.7918, critical value = 0.0397
# Rank 794: p-value = 0.7920, critical value = 0.0397
# Rank 795: p-value = 0.7928, critical value = 0.0398
# Rank 796: p-value = 0.7930, critical value = 0.0398
# Rank 797: p-value = 0.7995, critical value = 0.0399
# Rank 798: p-value = 0.7996, critical value = 0.0399
# Rank 799: p-value = 0.7997, critical value = 0.0400
# Rank 800: p-value = 0.8002, critical value = 0.0400
# Rank 801: p-value = 0.8005, critical value = 0.0401
# Rank 802: p-value = 0.8008, critical value = 0.0401
# Rank 803: p-value = 0.8048, critical value = 0.0402
# Rank 804: p-value = 0.8076, critical value = 0.0402
# Rank 805: p-value = 0.8084, critical value = 0.0403
# Rank 806: p-value = 0.8086, critical value = 0.0403
# Rank 807: p-value = 0.8090, critical value = 0.0404
# Rank 808: p-value = 0.8093, critical value = 0.0404
# Rank 809: p-value = 0.8097, critical value = 0.0405
# Rank 810: p-value = 0.8106, critical value = 0.0405
# Rank 811: p-value = 0.8126, critical value = 0.0406
# Rank 812: p-value = 0.8138, critical value = 0.0406
# Rank 813: p-value = 0.8147, critical value = 0.0406
# Rank 814: p-value = 0.8155, critical value = 0.0407
# Rank 815: p-value = 0.8164, critical value = 0.0408
# Rank 816: p-value = 0.8193, critical value = 0.0408
# Rank 817: p-value = 0.8200, critical value = 0.0408
# Rank 818: p-value = 0.8213, critical value = 0.0409
# Rank 819: p-value = 0.8218, critical value = 0.0410
# Rank 820: p-value = 0.8229, critical value = 0.0410
# Rank 821: p-value = 0.8238, critical value = 0.0411
# Rank 822: p-value = 0.8244, critical value = 0.0411
# Rank 823: p-value = 0.8246, critical value = 0.0411
# Rank 824: p-value = 0.8267, critical value = 0.0412
# Rank 825: p-value = 0.8287, critical value = 0.0413
# Rank 826: p-value = 0.8296, critical value = 0.0413
# Rank 827: p-value = 0.8300, critical value = 0.0413
# Rank 828: p-value = 0.8312, critical value = 0.0414
# Rank 829: p-value = 0.8316, critical value = 0.0415
# Rank 830: p-value = 0.8331, critical value = 0.0415
# Rank 831: p-value = 0.8333, critical value = 0.0416
# Rank 832: p-value = 0.8338, critical value = 0.0416
# Rank 833: p-value = 0.8348, critical value = 0.0416
# Rank 834: p-value = 0.8364, critical value = 0.0417
# Rank 835: p-value = 0.8375, critical value = 0.0418
# Rank 836: p-value = 0.8394, critical value = 0.0418
# Rank 837: p-value = 0.8405, critical value = 0.0418
# Rank 838: p-value = 0.8410, critical value = 0.0419
# Rank 839: p-value = 0.8413, critical value = 0.0420
# Rank 840: p-value = 0.8432, critical value = 0.0420
# Rank 841: p-value = 0.8439, critical value = 0.0421
# Rank 842: p-value = 0.8446, critical value = 0.0421
# Rank 843: p-value = 0.8449, critical value = 0.0421
# Rank 844: p-value = 0.8458, critical value = 0.0422
# Rank 845: p-value = 0.8465, critical value = 0.0423
# Rank 846: p-value = 0.8473, critical value = 0.0423
# Rank 847: p-value = 0.8487, critical value = 0.0423
# Rank 848: p-value = 0.8487, critical value = 0.0424
# Rank 849: p-value = 0.8491, critical value = 0.0425
# Rank 850: p-value = 0.8508, critical value = 0.0425
# Rank 851: p-value = 0.8523, critical value = 0.0426
# Rank 852: p-value = 0.8536, critical value = 0.0426
# Rank 853: p-value = 0.8538, critical value = 0.0427
# Rank 854: p-value = 0.8548, critical value = 0.0427
# Rank 855: p-value = 0.8557, critical value = 0.0428
# Rank 856: p-value = 0.8575, critical value = 0.0428
# Rank 857: p-value = 0.8584, critical value = 0.0428
# Rank 858: p-value = 0.8588, critical value = 0.0429
# Rank 859: p-value = 0.8591, critical value = 0.0430
# Rank 860: p-value = 0.8593, critical value = 0.0430
# Rank 861: p-value = 0.8594, critical value = 0.0431
# Rank 862: p-value = 0.8595, critical value = 0.0431
# Rank 863: p-value = 0.8603, critical value = 0.0432
# Rank 864: p-value = 0.8620, critical value = 0.0432
# Rank 865: p-value = 0.8621, critical value = 0.0433
# Rank 866: p-value = 0.8622, critical value = 0.0433
# Rank 867: p-value = 0.8623, critical value = 0.0433
# Rank 868: p-value = 0.8624, critical value = 0.0434
# Rank 869: p-value = 0.8629, critical value = 0.0435
# Rank 870: p-value = 0.8638, critical value = 0.0435
# Rank 871: p-value = 0.8639, critical value = 0.0436
# Rank 872: p-value = 0.8639, critical value = 0.0436
# Rank 873: p-value = 0.8640, critical value = 0.0437
# Rank 874: p-value = 0.8643, critical value = 0.0437
# Rank 875: p-value = 0.8643, critical value = 0.0438
# Rank 876: p-value = 0.8656, critical value = 0.0438
# Rank 877: p-value = 0.8662, critical value = 0.0439
# Rank 878: p-value = 0.8663, critical value = 0.0439
# Rank 879: p-value = 0.8666, critical value = 0.0440
# Rank 880: p-value = 0.8712, critical value = 0.0440
# Rank 881: p-value = 0.8719, critical value = 0.0441
# Rank 882: p-value = 0.8731, critical value = 0.0441
# Rank 883: p-value = 0.8734, critical value = 0.0442
# Rank 884: p-value = 0.8748, critical value = 0.0442
# Rank 885: p-value = 0.8751, critical value = 0.0443
# Rank 886: p-value = 0.8752, critical value = 0.0443
# Rank 887: p-value = 0.8764, critical value = 0.0444
# Rank 888: p-value = 0.8770, critical value = 0.0444
# Rank 889: p-value = 0.8831, critical value = 0.0445
# Rank 890: p-value = 0.8841, critical value = 0.0445
# Rank 891: p-value = 0.8845, critical value = 0.0446
# Rank 892: p-value = 0.8850, critical value = 0.0446
# Rank 893: p-value = 0.8861, critical value = 0.0447
# Rank 894: p-value = 0.8869, critical value = 0.0447
# Rank 895: p-value = 0.8874, critical value = 0.0448
# Rank 896: p-value = 0.8875, critical value = 0.0448
# Rank 897: p-value = 0.8877, critical value = 0.0449
# Rank 898: p-value = 0.8887, critical value = 0.0449
# Rank 899: p-value = 0.8889, critical value = 0.0450
# Rank 900: p-value = 0.8897, critical value = 0.0450
# Rank 901: p-value = 0.8902, critical value = 0.0451
# Rank 902: p-value = 0.8917, critical value = 0.0451
# Rank 903: p-value = 0.8929, critical value = 0.0452
# Rank 904: p-value = 0.8933, critical value = 0.0452
# Rank 905: p-value = 0.8947, critical value = 0.0453
# Rank 906: p-value = 0.8954, critical value = 0.0453
# Rank 907: p-value = 0.8971, critical value = 0.0454
# Rank 908: p-value = 0.8979, critical value = 0.0454
# Rank 909: p-value = 0.8985, critical value = 0.0455
# Rank 910: p-value = 0.8993, critical value = 0.0455
# Rank 911: p-value = 0.9010, critical value = 0.0456
# Rank 912: p-value = 0.9015, critical value = 0.0456
# Rank 913: p-value = 0.9031, critical value = 0.0457
# Rank 914: p-value = 0.9044, critical value = 0.0457
# Rank 915: p-value = 0.9064, critical value = 0.0458
# Rank 916: p-value = 0.9066, critical value = 0.0458
# Rank 917: p-value = 0.9080, critical value = 0.0459
# Rank 918: p-value = 0.9088, critical value = 0.0459
# Rank 919: p-value = 0.9094, critical value = 0.0460
# Rank 920: p-value = 0.9133, critical value = 0.0460
# Rank 921: p-value = 0.9139, critical value = 0.0461
# Rank 922: p-value = 0.9141, critical value = 0.0461
# Rank 923: p-value = 0.9143, critical value = 0.0462
# Rank 924: p-value = 0.9145, critical value = 0.0462
# Rank 925: p-value = 0.9148, critical value = 0.0463
# Rank 926: p-value = 0.9149, critical value = 0.0463
# Rank 927: p-value = 0.9153, critical value = 0.0464
# Rank 928: p-value = 0.9156, critical value = 0.0464
# Rank 929: p-value = 0.9159, critical value = 0.0465
# Rank 930: p-value = 0.9182, critical value = 0.0465
# Rank 931: p-value = 0.9188, critical value = 0.0466
# Rank 932: p-value = 0.9201, critical value = 0.0466
# Rank 933: p-value = 0.9218, critical value = 0.0467
# Rank 934: p-value = 0.9240, critical value = 0.0467
# Rank 935: p-value = 0.9241, critical value = 0.0468
# Rank 936: p-value = 0.9242, critical value = 0.0468
# Rank 937: p-value = 0.9273, critical value = 0.0469
# Rank 938: p-value = 0.9300, critical value = 0.0469
# Rank 939: p-value = 0.9317, critical value = 0.0469
# Rank 940: p-value = 0.9320, critical value = 0.0470
# Rank 941: p-value = 0.9336, critical value = 0.0471
# Rank 942: p-value = 0.9345, critical value = 0.0471
# Rank 943: p-value = 0.9345, critical value = 0.0471
# Rank 944: p-value = 0.9351, critical value = 0.0472
# Rank 945: p-value = 0.9359, critical value = 0.0473
# Rank 946: p-value = 0.9363, critical value = 0.0473
# Rank 947: p-value = 0.9366, critical value = 0.0474
# Rank 948: p-value = 0.9382, critical value = 0.0474
# Rank 949: p-value = 0.9386, critical value = 0.0474
# Rank 950: p-value = 0.9389, critical value = 0.0475
# Rank 951: p-value = 0.9430, critical value = 0.0476
# Rank 952: p-value = 0.9432, critical value = 0.0476
# Rank 953: p-value = 0.9436, critical value = 0.0476
# Rank 954: p-value = 0.9448, critical value = 0.0477
# Rank 955: p-value = 0.9464, critical value = 0.0478
# Rank 956: p-value = 0.9473, critical value = 0.0478
# Rank 957: p-value = 0.9480, critical value = 0.0479
# Rank 958: p-value = 0.9490, critical value = 0.0479
# Rank 959: p-value = 0.9494, critical value = 0.0479
# Rank 960: p-value = 0.9505, critical value = 0.0480
# Rank 961: p-value = 0.9508, critical value = 0.0481
# Rank 962: p-value = 0.9534, critical value = 0.0481
# Rank 963: p-value = 0.9541, critical value = 0.0481
# Rank 964: p-value = 0.9589, critical value = 0.0482
# Rank 965: p-value = 0.9609, critical value = 0.0483
# Rank 966: p-value = 0.9611, critical value = 0.0483
# Rank 967: p-value = 0.9613, critical value = 0.0484
# Rank 968: p-value = 0.9614, critical value = 0.0484
# Rank 969: p-value = 0.9654, critical value = 0.0485
# Rank 970: p-value = 0.9679, critical value = 0.0485
# Rank 971: p-value = 0.9700, critical value = 0.0486
# Rank 972: p-value = 0.9711, critical value = 0.0486
# Rank 973: p-value = 0.9741, critical value = 0.0486
# Rank 974: p-value = 0.9749, critical value = 0.0487
# Rank 975: p-value = 0.9751, critical value = 0.0488
# Rank 976: p-value = 0.9751, critical value = 0.0488
# Rank 977: p-value = 0.9757, critical value = 0.0489
# Rank 978: p-value = 0.9761, critical value = 0.0489
# Rank 979: p-value = 0.9762, critical value = 0.0490
# Rank 980: p-value = 0.9763, critical value = 0.0490
# Rank 981: p-value = 0.9763, critical value = 0.0491
# Rank 982: p-value = 0.9785, critical value = 0.0491
# Rank 983: p-value = 0.9794, critical value = 0.0491
# Rank 984: p-value = 0.9803, critical value = 0.0492
# Rank 985: p-value = 0.9814, critical value = 0.0493
# Rank 986: p-value = 0.9815, critical value = 0.0493
# Rank 987: p-value = 0.9822, critical value = 0.0494
# Rank 988: p-value = 0.9829, critical value = 0.0494
# Rank 989: p-value = 0.9849, critical value = 0.0495
# Rank 990: p-value = 0.9856, critical value = 0.0495
# Rank 991: p-value = 0.9856, critical value = 0.0496
# Rank 992: p-value = 0.9884, critical value = 0.0496
# Rank 993: p-value = 0.9906, critical value = 0.0496
# Rank 994: p-value = 0.9907, critical value = 0.0497
# Rank 995: p-value = 0.9934, critical value = 0.0498
# Rank 996: p-value = 0.9942, critical value = 0.0498
# Rank 997: p-value = 0.9943, critical value = 0.0499
# Rank 998: p-value = 0.9945, critical value = 0.0499
# Rank 999: p-value = 0.9980, critical value = 0.0500
# Rank 1000: p-value = 0.9993, critical value = 0.0500
# No p-values are smaller than their associated critical values.

# %% [markdown]
# Third, set the sample 1 and sample 2 means to be 1 and 2 respectively, and re-run the exercise. What do you notice?

# %%
# Parameters
mu_1 = 1
mu_2 = 2
sigma = 1
N = 10
num_simulations = 1000

# Generate Samples and perform t-tests for all simulations
p_values = []
for _ in range(num_simulations):
    X1 = np.random.normal(mu_1, sigma, N)
    X2 = np.random.normal(mu_2, sigma, N)
    tstat, p_val = st.ttest_ind(X1, X2)
    p_values.append(p_val)

#Percentage of significant results out of all Simulations
significant_results = [p_val for p_val in p_values if p_val < alpha]
percentage_significant = (len(significant_results) / num_simulations) * 100
print(f"\nPercentage of simulations yielding a statistically significant result: {percentage_significant:.2f}%")


#Bonferroni Correction
m = num_simulations
alpha = 0.05
bonferroni_alpha = alpha / m

# Convert p_values to a NumPy array
p_values = np.array(p_values) #This line has been added to fix the error

# Calculate the number of significant results after correction
significant_count = np.sum(p_values < bonferroni_alpha)

# Results
print(f"\nBonferroni corrected alpha: {bonferroni_alpha:.6f}")
print(f'Number of significant p-values after Bonferroni correction: {significant_count}')


#Benjamini-Hochberg Procedure
#Rank p-values in ascending order
#p_values = np.array(p_values) # This line was removed to avoid reassigning p_values to an array again.

ranked_indices = np.argsort(p_values)
ranked_p_values = p_values[ranked_indices]

#Critical value for each p-value as (i/n)Q, where i is the rank, n is the total number of tests, and Q is the false discovery rate (a percentage) that you choose (typically 0.05).
Q = 0.05 #false discovery rate
n = len(p_values)
critical_values = (np.arange(1, n + 1) / n) * Q

#Find the largest value that is smaller than its associated critical value
valid_p_mask = ranked_p_values < critical_values
if np.any(valid_p_mask):
    largest_valid_p = ranked_p_values[valid_p_mask][-1]  # Take the last valid p-value
    print(f'The largest p-value smaller than its critical value is: {largest_valid_p:.4f}')
else:
    print('No p-values are smaller than their associated critical values.')
# Out:
# Percentage of simulations yielding a statistically significant result: 57.10%
#
# Bonferroni corrected alpha: 0.000050
# Number of significant p-values after Bonferroni correction: 10
# The largest p-value smaller than its critical value is: 0.0195

# %% [markdown]
# What if you make the difference between means even greater?

# %%
# Parameters
mu_1 = 1
mu_2 = 6
sigma = 1
N = 10
num_simulations = 1000

# Generate Samples and perform t-tests for all simulations
p_values = []
for _ in range(num_simulations):
    X1 = np.random.normal(mu_1, sigma, N)
    X2 = np.random.normal(mu_2, sigma, N)
    tstat, p_val = st.ttest_ind(X1, X2)
    p_values.append(p_val)

#Percentage of significant results out of all Simulations
significant_results = [p_val for p_val in p_values if p_val < alpha]
percentage_significant = (len(significant_results) / num_simulations) * 100
print(f"\nPercentage of simulations yielding a statistically significant result: {percentage_significant:.2f}%")


#Bonferroni Correction
m = num_simulations
alpha = 0.05
bonferroni_alpha = alpha / m

# Convert p_values to a NumPy array
p_values = np.array(p_values) #This line has been added to fix the error

# Calculate the number of significant results after correction
significant_count = np.sum(p_values < bonferroni_alpha)

# Results
print(f"\nBonferroni corrected alpha: {bonferroni_alpha:.6f}")
print(f'Number of significant p-values after Bonferroni correction: {significant_count}')


#Benjamini-Hochberg Procedure
#Rank p-values in ascending order
#p_values = np.array(p_values) # This line was removed to avoid reassigning p_values to an array again.

ranked_indices = np.argsort(p_values)
ranked_p_values = p_values[ranked_indices]

#Critical value for each p-value as (i/n)Q, where i is the rank, n is the total number of tests, and Q is the false discovery rate (a percentage) that you choose (typically 0.05).
Q = 0.05 #false discovery rate
n = len(p_values)
critical_values = (np.arange(1, n + 1) / n) * Q

#Find the largest value that is smaller than its associated critical value
valid_p_mask = ranked_p_values < critical_values
if np.any(valid_p_mask):
    largest_valid_p = ranked_p_values[valid_p_mask][-1]  # Take the last valid p-value
    print(f'The largest p-value smaller than its critical value is: {largest_valid_p:.4f}')
else:
    print('No p-values are smaller than their associated critical values.')
# Out:
# Percentage of simulations yielding a statistically significant result: 100.00%
#
# Bonferroni corrected alpha: 0.000050
# Number of significant p-values after Bonferroni correction: 1000
# The largest p-value smaller than its critical value is: 0.0000
